# %% [raw]
# Business goal
# 1. Identify thee best customers (develop a ranking mechanism)
# 2. The budget is $1,000.
# 3. No indication was given about how much each coupon would be worth — it's for you to decide.
# 4. The coupons need to be good enough to prompt people to actually use them.
# 5. They can't be too high because:
#      - That reduces the number of customers who get them.
#      - It would be like giving away money.
#      - Due to price dumping, it could be illegal.
#
# 6. Assumptions
#      - a 30% discount is already very enticing;
#      - weighted average of number of transactions and amount spend is good criteria to rank customers.

# %%
import pandas as pd

data = pd.read_csv("rfm_xmas19.txt", parse_dates=["trans_date"])
#parse_dates allows us to immediately set the appropriate date type to the selected columns
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125000 entries, 0 to 124999
# Data columns (total 3 columns):
# customer_id    125000 non-null object
# trans_date     125000 non-null datetime64[ns]
# tran_amount    125000 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.9+ MB
# None

# %%
data.head()
# Out:
#   customer_id trans_date  tran_amount
# 0      FM5295 2017-11-11           35
# 1      FM4768 2019-12-15           39
# 2      FM2122 2017-11-26           52
# 3      FM1217 2016-08-16           99
# 4      FM1850 2018-08-20           78

# %% [markdown]
# #### Last Purchase by Custumer ID

# %%
group_by_customer=data.groupby(['customer_id'])
best_churn= data[['customer_id','trans_date']].groupby(['customer_id']).max()

# %%
best_churn.head()
# Out:
#             trans_date
# customer_id
# FM1112      2019-10-14
# FM1113      2019-11-09
# FM1114      2019-11-12
# FM1115      2019-12-05
# FM1116      2019-05-25

# %% [markdown]
# #### Customers Who Churned

# %%
import datetime
cutoff_day = datetime.datetime(2019, 10, 16) ###assigning it datetimee
print(type(cutoff_day))
best_churn.info()
best_churn["trans_date"]=pd.to_datetime(best_churn["trans_date"])  ##converting it datetimee
best_churn['churned']=best_churn["trans_date"].apply(lambda x: 1 if (x-cutoff_day).days<0 else 0)
# Out:
# <class 'datetime.datetime'>
# <class 'pandas.core.frame.DataFrame'>
# Index: 6889 entries, FM1112 to FM9000
# Data columns (total 1 columns):
# trans_date    6889 non-null datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 107.6+ KB

# %%
best_churn.head()
# Out:
#             trans_date  churned
# customer_id
# FM1112      2019-10-14        1
# FM1113      2019-11-09        0
# FM1114      2019-11-12        0
# FM1115      2019-12-05        0
# FM1116      2019-05-25        1

# %% [markdown]
# #### Ranking Mechanism to find the best customer
#
# 1. Amount spent and
# 2. number of purchases made, and
# The scores should be the same weight. This means that a customer who spent a lot is worth as much as someone who made many purchases.
# 3. Since the values are different in scale, it will have an impact on the ranking, so using the min-max scaling is the solution.

# %%
best_churn["nr_of_transactions"] = group_by_customer.size()
best_churn["amount_spent"] = group_by_customer['tran_amount'].sum()
best_churn.drop(columns=['trans_date'],inplace=True)
best_churn.sample(5)
# Out:
#              churned  nr_of_transactions  amount_spent
# customer_id
# FM2877             0                  24          1677
# FM7207             0                  12           604
# FM1548             0                  23          1755
# FM4887             0                  23          1516
# FM2058             0                  26          1776

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
def normalize(cols):
   mm_scaler = preprocessing.MinMaxScaler()
   for col in cols:
     best_churn['scaled_{}'.format(col)]= mm_scaler.fit_transform(best_churn[[col]])
   return best_churn

# %%
best_churn=normalize(['nr_of_transactions','amount_spent'])

# %%
best_churn.head()
# Out:
#              churned  nr_of_transactions  amount_spent  \
# customer_id
# FM1112             1                  15          1012
# FM1113             0                  20          1490
# FM1114             0                  19          1432
# FM1115             0                  22          1659
# FM1116             1                  13           857
#
#              scaled_nr_of_transactions  scaled_amount_spent
# customer_id
# FM1112                        0.314286             0.309986
# FM1113                        0.457143             0.481681
# FM1114                        0.428571             0.460848
# FM1115                        0.514286             0.542385
# FM1116                        0.257143             0.254310

# %% [markdown]
# #### Scaled weighted score for number of transactions and amount spent

# %%
best_churn['score']=(best_churn['scaled_nr_of_transactions']*0.5+best_churn['scaled_amount_spent']*0.5)*100

# %%
best_churn.head()
# Out:
#              churned  nr_of_transactions  amount_spent  \
# customer_id
# FM1112             1                  15          1012
# FM1113             0                  20          1490
# FM1114             0                  19          1432
# FM1115             0                  22          1659
# FM1116             1                  13           857
#
#              scaled_nr_of_transactions  scaled_amount_spent      score
# customer_id
# FM1112                        0.314286             0.309986  31.213567
# FM1113                        0.457143             0.481681  46.941195
# FM1114                        0.428571             0.460848  44.470956
# FM1115                        0.514286             0.542385  52.833539
# FM1116                        0.257143             0.254310  25.572660

# %%
best_churn.sort_values(by='score', ascending=False,inplace=True)

# %%
best_churn.head()
# Out:
#              churned  nr_of_transactions  amount_spent  \
# customer_id
# FM4424             0                  39          2933
# FM4320             1                  38          2647
# FM3799             1                  36          2513
# FM5109             0                  35          2506
# FM3805             1                  35          2453
#
#              scaled_nr_of_transactions  scaled_amount_spent       score
# customer_id
# FM4424                        1.000000             1.000000  100.000000
# FM4320                        0.971429             0.897270   93.434934
# FM3799                        0.914286             0.849138   88.171182
# FM5109                        0.885714             0.846624   86.616892
# FM3805                        0.885714             0.827586   85.665025

# %% [markdown]
# Identify the following based on the business goal
# 1. number of coupouns and
# 2. the value for each of the coupon and
# 3. who should be getting it

# %%
coupon = data['tran_amount'].mean()*0.30
nr_of_customers = 1000//coupon

# %%
nr_of_customers
# Out:
# 51.0

# %% [markdown]
# #### so final we have a $20 coupoun for 50 churned customers

# %%
top_50_churned=best_churn.loc[best_churn["churned"] == 1].head(50)

# %%
top_50_churned
# Out:
#              churned  nr_of_transactions  amount_spent  \
# customer_id
# FM4320             1                  38          2647
# FM3799             1                  36          2513
# FM3805             1                  35          2453
# FM5752             1                  33          2612
# FM4074             1                  34          2462
# FM1215             1                  35          2362
# FM2620             1                  35          2360
# FM1580             1                  33          2329
# FM2951             1                  32          2382
# FM3163             1                  31          2413
# FM5868             1                  31          2260
# FM1695             1                  32          2174
# FM1865             1                  31          2245
# FM1757             1                  31          2238
# FM3362             1                  30          2303
# FM3356             1                  31          2221
# FM1978             1                  31          2220
# FM1541             1                  30          2273
# FM4303             1                  31          2181
# FM3165             1                  30          2202
# FM2361             1                  30          2193
# FM3530             1                  30          2186
# FM4139             1                  31          2099
# FM2482             1                  31          2098
