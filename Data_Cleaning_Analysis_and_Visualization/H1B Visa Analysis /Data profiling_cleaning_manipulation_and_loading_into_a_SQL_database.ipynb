# %%
import requests
import json
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# ### LOADING THE DATA

# %%
data = pd.read_csv("/Users/ankitkothari/Documents/COMPLETED_PROJECTS/H1B_data_analysis/h1b_dump_data/optimized_h1b_data.csv")
data= data.drop(columns=['Unnamed: 0'])
data.head()
# Out:
#    Fiscal Year                     Employer  Initial Approvals  \
# 0         2018          REDDY GI ASSOCIATES                0.0
# 1         2018      ADMIRAL INSTRUMENTS LLC                1.0
# 2         2018      THE BELPORT COMPANY INC                0.0
# 3         2018  CALLAWAY GOLF SALES COMPANY                1.0
# 4         2018          PAYSAFE PARTNERS LP                0.0
#
#    Initial Denials  Continuing Approvals  Continuing Denials  NAICS State  \
# 0              0.0                   0.0                 1.0     99    AZ
# 1              0.0                   0.0                 0.0     33    AZ
# 2              1.0                   0.0                 0.0     33    CA
# 3              0.0                   0.0                 0.0     33    CA
# 4              0.0                   1.0                 0.0     52    CA
#
#         City      ZIP
# 0       MESA  85209.0
# 1      TEMPE  85281.0
# 2  CAMARILLO  93012.0
# 3   CARLSBAD  92008.0
# 4     IRVINE  92612.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 585744 entries, 0 to 585743
# Data columns (total 10 columns):
# Fiscal Year             585744 non-null int64
# Employer                585576 non-null object
# Initial Approvals       585673 non-null float64
# Initial Denials         585742 non-null float64
# Continuing Approvals    585626 non-null float64
# Continuing Denials      585740 non-null float64
# NAICS                   585744 non-null int64
# State                   585581 non-null object
# City                    585720 non-null object
# ZIP                     585596 non-null float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 44.7+ MB

# %%
data.columns
# Out:
# Index(['Fiscal Year', 'Employer', 'Initial Approvals', 'Initial Denials',
#        'Continuing Approvals', 'Continuing Denials', 'NAICS', 'State', 'City',
#        'ZIP'],
#       dtype='object')

# %% [markdown]
# ### DROPPING COLUMNS WHICH HAVE INCOMPLETE DATA WHICH IS CRITICAL TO THE ANALYSIS

# %%
data= data.dropna(subset=['Fiscal Year','Employer','State','Initial Approvals',
       'Initial Denials', 'Continuing Approvals', 'Continuing Denials'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 585279 entries, 0 to 585743
# Data columns (total 10 columns):
# Fiscal Year             585279 non-null int64
# Employer                585279 non-null object
# Initial Approvals       585279 non-null float64
# Initial Denials         585279 non-null float64
# Continuing Approvals    585279 non-null float64
# Continuing Denials      585279 non-null float64
# NAICS                   585279 non-null int64
# State                   585279 non-null object
# City                    585276 non-null object
# ZIP                     585254 non-null float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 49.1+ MB

# %% [markdown]
# ### ADDING LATITUDE AND LONGITUDE COLUMNS FOR EACH STATE THAT WILL BE USED IN MAP PLOTS

# %%
us_states = data['State'].unique()
print(type(us_states))
print(us_states)
# Out:
# <class 'numpy.ndarray'>
# ['AZ' 'CA' 'CT' 'DC' 'DE' 'FL' 'GA' 'HI' 'ID' 'IL' 'IN' 'KS' 'KY' 'LA'
#  'MA' 'MD' 'MO' 'MP' 'NC' 'ND' 'NJ' 'NY' 'OH' 'PA' 'PR' 'RI' 'SD' 'TN'
#  'TX' 'VA' 'WA' 'WI' 'ME' 'AE' 'NH' 'MI' 'SC' 'WV' 'CO' 'AR' 'UT' 'OK'
#  'MN' 'NE' 'VT' 'NV' 'AL' 'MS' 'IA' 'GU' 'OR' 'NM' 'AK' 'WY' 'MT' 'VI'
#  '\x04' 'AP' 'FM']

# %%
us_states = np.delete(us_states, np.where(us_states == '\x04'))
print(us_states)
# Out:
# ['AZ' 'CA' 'CT' 'DC' 'DE' 'FL' 'GA' 'HI' 'ID' 'IL' 'IN' 'KS' 'KY' 'LA'
#  'MA' 'MD' 'MO' 'MP' 'NC' 'ND' 'NJ' 'NY' 'OH' 'PA' 'PR' 'RI' 'SD' 'TN'
#  'TX' 'VA' 'WA' 'WI' 'ME' 'AE' 'NH' 'MI' 'SC' 'WV' 'CO' 'AR' 'UT' 'OK'
#  'MN' 'NE' 'VT' 'NV' 'AL' 'MS' 'IA' 'GU' 'OR' 'NM' 'AK' 'WY' 'MT' 'VI'
#  'AP' 'FM']

# %%
cordinates= []
points = {}
o=0
api_file = open("/Users/ankitkothari/Documents/COMPLETED_PROJECTS/H1B_data_analysis/api.txt", 'r')
api_key = api_file.read()

cordinates_us_states = pd.DataFrame()
for state in us_states:
    response = requests.get("https://maps.googleapis.com/maps/api/geocode/json?components=administrative_area:{}|country:US&key={}".format(state, api_key))
    content = response.json()
    for i in content['results']:
      cord = (i['geometry']['location'])
      for j in cord:
        cordinates_us_states.loc[o,'long'] = cord['lng']
        cordinates_us_states.loc[o,'lang'] = cord['lat']
        cordinates_us_states.loc[o,'state'] = state
    o=o+1
    cordinates.append(points)

print(cordinates_us_states)
# Out:
#           long       lang state
# 0  -111.093731  34.048928    AZ
# 1  -119.417932  36.778261    CA
# 2   -73.087749  41.603221    CT
# 3   -77.036871  38.907192    DC
# 4   -75.527670  38.910832    DE
# 5   -81.515754  27.664827    FL
# 6   -82.900075  32.165622    GA
# 7  -155.582782  19.896766    HI
# 8  -114.742041  44.068202    ID
# 9   -89.398528  40.633125    IL
# 11  -98.484246  39.011902    KS
# 12  -84.270018  37.839333    KY
# 13  -91.962333  30.984298    LA
# 14  -71.382437  42.407211    MA
# 15  -76.641271  39.045755    MD
# 16  -91.831833  37.964253    MO
# 18  -79.019300  35.759573    NC
# 19 -101.002012  47.551493    ND
# 20  -74.405661  40.058324    NJ
# 21  -74.005973  40.712775    NY
# 22  -82.907123  40.417287    OH
# 23  -77.194525  41.203322    PA
# 25  -71.477429  41.580095    RI
# 26  -99.901813  43.969515    SD
# 27  -86.580447  35.517491    TN
# 28  -99.901813  31.968599    TX
# 29  -78.656894  37.431573    VA
# 30 -120.740139  47.751074    WA
# 31  -88.787868  43.784440    WI
# 32  -69.445469  45.253783    ME
# 34  -71.572395  43.193852    NH
# 35  -85.602364  44.314844    MI
# 36  -81.163725  33.836081    SC
# 37  -80.454903  38.597626    WV
# 38 -105.782067  39.550051    CO
# 39  -91.831833  35.201050    AR
# 40 -111.093731  39.320980    UT
# 41  -97.092877  35.007752    OK
# 42  -94.685900  46.729553    MN
# 43  -99.901813  41.492537    NE
# 44  -72.577841  44.558803    VT
# 45 -116.419389  38.802610    NV
# 46  -86.902298  32.318231    AL
# 47  -89.398528  32.354668    MS
# 48  -93.097702  41.878003    IA
# 51 -105.870090  34.519940    NM
# 52 -149.493673  64.200841    AK
# 53 -107.290284  43.075968    WY
# 54 -110.362566  46.879682    MT

# %%
data = data.merge(cordinates_us_states, left_on='State', right_on='state', how='left')

# %%
data=data.iloc[:,0:-1]
data.head(100)
# Out:
#     Fiscal Year                            Employer  Initial Approvals  \
# 0          2018                 REDDY GI ASSOCIATES                0.0
# 1          2018             ADMIRAL INSTRUMENTS LLC                1.0
# 2          2018             THE BELPORT COMPANY INC                0.0
# 3          2018         CALLAWAY GOLF SALES COMPANY                1.0
# 4          2018                 PAYSAFE PARTNERS LP                0.0
# 5          2018  STATE OF CA SECY OF STATE S OFFICE                0.0
# 6          2018  EMERALD HEALTH PHARMACEUTICALS INC                0.0
# 7          2018  GONSALVES & SANTUCCI INC DBA THE C                1.0
# 8          2018                         A T KEARNEY                1.0
# 9          2018                      AMERI INFO INC                1.0
# 10         2018          SAN JOSE STATE UNIVERSISTY                1.0
# 11         2018           LIN ZHI INTERNATIONAL INC                1.0
# 12         2018                     FUNKTRONIC LABS                1.0
# 13         2018                        ELM EAST LLC                0.0
# 14         2018         BOEHRINGER INGELHEIM PHARMA                0.0
# 15         2018     GLOBAL TAX NETWORK ATLANTIC LLC                1.0
# 16         2018  DISTRICT OF COLUMBIA PUBLC SCHOOLS                1.0
# 17         2018                 PULMONICS PLUS PLLC                1.0
# 18         2018                  AIRPORT SHERPA LLC                0.0
# 19         2018  CANCER TREATMENT CTRS OF AMERICA G                0.0
# 20         2018                      AUTOSPORTS LLC                1.0
# 21         2018                WHITEHOUSE GROUP INC                1.0
# 22         2018         DHL STANDARD FORWARDING LLC                1.0
# 23         2018       FLORIDA PROPERTY ADVISORS LLC                1.0
# 24         2018                   YUKA CLOTHING INC                0.0
# 25         2018  ACROSS BORDERS MGT CONSULTING GP I                1.0
# 26         2018            PIEDMONT ATHENS REGIONAL                1.0
# 27         2018  GEORGIA DEPARTMENT OF NATURAL RESO                1.0
# 28         2018        ALLIANT HEALTH SOLUTIONS INC                1.0
# 29         2018                        CJ GROUP LLC                0.0
# ..          ...                                 ...                ...
# 70         2018       PARAMOUNT GROUP MANAGEMENT LP                1.0
# 71         2018    PARAG DIAMOND DBA PARAMOUNT GEMS                1.0
# 72         2018                         EFFY CO INC                0.0
# 73         2018                       DIGIXFORM INC                0.0
# 74         2018       EXODUS INTEGRITY SERVICES INC                1.0
# 75         2018  FEDEX SUPPLY CHAIN LOGISTICS & ELE                0.0
# 76         2018      HARTE HANKS STRATEGIC MKTG INC                0.0
# 77         2018     WILLOWOOD FAMILY DENTAL CARE PC                1.0
# 78         2018      CBS CORP BUS SOLNS AMERICA INC                0.0
# 79         2018           DELOITTE CONSULTING OVERS                0.0
# 80         2018              ACCESSDENTALCENTER INC                0.0
# 81         2018                  CITY OF PITTSBURGH                1.0
# 82         2018   BLUE OCEAN INTERNATIONAL BANK LLC                1.0
# 83         2018                             HNR LLC                0.0
# 84         2018               NATIONAL MUSIC MUSEUM                1.0
# 85         2018                       SAI LEELA INC                0.0
# 86         2018                       IBIO CDMO LLC                1.0
# 87         2018  PROFESSIONAL MEDICAL EQUIPMENT INC                0.0
# 88         2018            PIN POINT MANAGEMENT LLC                0.0
# 89         2018       MARITECH COMMERCIAL TEXAS INC                0.0
# 90         2018  BHR ENTERPRISES LLC DBA ROXON SOLN                0.0
# 91         2018  PANENERGY SERVICES LIMITED PARTNER                0.0
# 92         2018            SPIRIT ENVIRONMENTAL LLC                0.0
# 93         2018              CLOUD RACK SYSTEMS INC                0.0
# 94         2018           ABC HOBBIES RADIO CONTROL                0.0
# 95         2018                SDT DISTRIBUTION INC                1.0
# 96         2018             ADALINE INFOSYSTEMS LTD                0.0
# 97         2018                      OPENLEGACY INC                0.0
# 98         2018  AAA VENTURE LLC DBA 1947 INDIAN RE                0.0
# 99         2018            LYNDEN CHRISTIAN SCHOOLS                1.0
#
#     Initial Denials  Continuing Approvals  Continuing Denials  NAICS State  \
# 0               0.0                   0.0                 1.0     99    AZ
# 1               0.0                   0.0                 0.0     33    AZ
# 2               1.0                   0.0                 0.0     33    CA
# 3               0.0                   0.0                 0.0     33    CA
# 4               0.0                   1.0                 0.0     52    CA
# 5               0.0                   0.0                 1.0     54    CA
# 6               0.0                   0.0                 1.0     54    CA
# 7               0.0                   0.0                 0.0     23    CA
# 8               0.0                   0.0                 0.0     99    CA
# 9               0.0                   0.0                 0.0     54    CA
# 10              0.0                   0.0                 0.0     61    CA
# 11              0.0                   0.0                 0.0     32    CA
# 12              0.0                   0.0                 0.0     51    CA
# 13              0.0                   1.0                 0.0     54    CA
# 14              0.0                   1.0                 0.0     56    CT
# 15              0.0                   0.0                 0.0     54    CT
# 16              0.0                   0.0                 0.0     61    DC
# 17              0.0                   0.0                 0.0     62    DC
# 18              1.0                   0.0                 0.0     99    DE
# 19              1.0                   0.0                 0.0     62    FL
# 20              0.0                   0.0                 0.0     81    FL
# 21              0.0                   0.0                 0.0     54    FL
# 22              0.0                   0.0                 0.0     49    FL
# 23              0.0                   0.0                 0.0     53    FL
# 24              0.0                   1.0                 0.0     44    FL
# 25              0.0                   0.0                 0.0     54    FL
# 26              0.0                   0.0                 0.0     62    GA
# 27              0.0                   0.0                 0.0     92    GA
# 28              0.0                   0.0                 0.0     54    GA
# 29              0.0                   0.0                 1.0     99    HI
# ..              ...                   ...                 ...    ...   ...
# 70              0.0                   0.0                 0.0     52    NY
# 71              0.0                   0.0                 0.0     42    NY
# 72              0.0                   1.0                 0.0     44    NY
# 73              1.0                   0.0                 0.0     54    NY
# 74              0.0                   0.0                 0.0     56    OH
# 75              0.0                   1.0                 0.0     54    PA
# 76              0.0                   1.0                 0.0     54    PA
# 77              0.0                   0.0                 0.0     54    PA
# 78              0.0                   1.0                 0.0     51    PA
# 79              0.0                   1.0                 0.0     99    PA
# 80              0.0                   1.0                 0.0     62    PA
# 81              0.0                   0.0                 0.0     92    PA
# 82              0.0                   0.0                 0.0     52    PR
# 83              1.0                   0.0                 0.0     72    RI
# 84              0.0                   0.0                 0.0     71    SD
# 85              0.0                   0.0                 1.0     72    TN
# 86              0.0                   0.0                 0.0     32    TX
# 87              1.0                   0.0                 0.0     42    TX
# 88              0.0                   0.0                 1.0     62    TX
# 89              0.0                   1.0                 0.0     48    TX
# 90              1.0                   0.0                 0.0     54    TX
# 91              0.0                   1.0                 0.0     48    TX
# 92              0.0                   1.0                 0.0     54    TX
# 93              2.0                   1.0                 0.0     54    TX
# 94              0.0                   1.0                 0.0     99    TX
# 95              0.0                   0.0                 0.0     99    TX
# 96              1.0                   0.0                 0.0     54    VA
# 97              1.0                   0.0                 0.0     54    VA
# 98              1.0                   0.0                 0.0     99    VA
# 99              0.0                   0.0                 0.0     61    WA
#
#                   City      ZIP        long       lang
# 0                 MESA  85209.0 -111.093731  34.048928
# 1                TEMPE  85281.0 -111.093731  34.048928
# 2            CAMARILLO  93012.0 -119.417932  36.778261
# 3             CARLSBAD  92008.0 -119.417932  36.778261
# 4               IRVINE  92612.0 -119.417932  36.778261
# 5           SACRAMENTO  95814.0 -119.417932  36.778261
# 6            SAN DIEGO  92121.0 -119.417932  36.778261
# 7        SAN FRANCISCO  94111.0 -119.417932  36.778261
# 8        SAN FRANCISCO  94111.0 -119.417932  36.778261
# 9             SAN JOSE  95129.0 -119.417932  36.778261
# 10            SAN JOSE  95192.0 -119.417932  36.778261
# 11         SANTA CLARA  95051.0 -119.417932  36.778261
# 12      SOUTH EL MONTE  91733.0 -119.417932  36.778261
# 13           SUNNYVALE  94086.0 -119.417932  36.778261
# 14          RIDGEFIELD   6877.0  -73.087749  41.603221
# 15            STAMFORD   6902.0  -73.087749  41.603221
# 16          WASHINGTON  20002.0  -77.036871  38.907192
# 17          WASHINGTON  20036.0  -77.036871  38.907192
# 18          WILMINGTON  19801.0  -75.527670  38.910832
# 19          BOCA RATON  33487.0  -81.515754  27.664827
# 20         CASSELBERRY  32707.0  -81.515754  27.664827
# 21     FORT LAUDERDALE  33309.0  -81.515754  27.664827
# 22               MIAMI  33126.0  -81.515754  27.664827
# 23               MIAMI  33156.0  -81.515754  27.664827
# 24               MIAMI  33181.0  -81.515754  27.664827
# 25          MOUNT DORA  32757.0  -81.515754  27.664827
# 26              ATHENS  30606.0  -82.900075  32.165622
# 27             ATLANTA  30334.0  -82.900075  32.165622
# 28             ATLANTA  30346.0  -82.900075  32.165622
# 29            HONOLULU  96814.0 -155.582782  19.896766
# ..                 ...      ...         ...        ...
# 70            NEW YORK  10019.0  -74.005973  40.712775
# 71            NEW YORK  10036.0  -74.005973  40.712775
# 72            NEW YORK  10036.0  -74.005973  40.712775
# 73            NEWBURGH  12550.0  -74.005973  40.712775
# 74          WILLOUGHBY  44094.0  -82.907123  40.417287
# 75  CRANBERRY TOWNSHIP  16066.0  -77.194525  41.203322
# 76        FEASTERVILLE  19053.0  -77.194525  41.203322
# 77           LEVITTOWN  19054.0  -77.194525  41.203322
# 78        PHILADELPHIA  19103.0  -77.194525  41.203322
# 79        PHILADELPHIA  19103.0  -77.194525  41.203322
# 80        PHILADELPHIA  19105.0  -77.194525  41.203322
# 81          PITTSBURGH  15216.0  -77.194525  41.203322
# 82            SAN JUAN    918.0         NaN        NaN
# 83            JOHNSTON   2919.0  -71.477429  41.580095
# 84          VERMILLION  57069.0  -99.901813  43.969515
# 85           NASHVILLE  37214.0  -86.580447  35.517491
# 86               BRYAN  77807.0  -99.901813  31.968599
# 87            BULVERDE  78163.0  -99.901813  31.968599
# 88              DALLAS  75208.0  -99.901813  31.968599
# 89             HOUSTON  77029.0  -99.901813  31.968599
# 90             HOUSTON  77043.0  -99.901813  31.968599
# 91             HOUSTON  77056.0  -99.901813  31.968599
# 92             HOUSTON  77070.0  -99.901813  31.968599
# 93              IRVING  75038.0  -99.901813  31.968599
# 94              LAREDO  78041.0  -99.901813  31.968599
# 95          SUGAR LAND  77498.0  -99.901813  31.968599
# 96             ASHBURN  20148.0  -78.656894  37.431573
# 97              RESTON  20190.0  -78.656894  37.431573
# 98            STERLING  20164.0  -78.656894  37.431573
# 99              LYNDEN  98264.0 -120.740139  47.751074
#
# [100 rows x 12 columns]

# %%
data.shape
# Out:
# (585279, 12)

# %% [markdown]
# ### DATA CLEANING: CLEANING EMPLOYERS NAME
#     - REMOVING SPACES
#     - REPLACING EMPLOYER WITH MULTIPLE NAMES DUE TO BAD DATA WITH ONE NAME

# %% [markdown]
# ##### For example AMAZON uses variery of names to file based on there subcidiary, But they all come under Amazon so replacing them with AMAZON for analysis makes sense

# %%
pattern = r"\bAMAZON\b\s*.*"
amazon= data[data['Employer'].str.contains(pattern, na=False)]['Employer']
print(amazon.unique())
# Out:
# ['AMAZON CORPORATE LLC' 'AMAZON WEB SVCS INC' 'AMAZON COM AZDC LLC'
#  'AMAZON PAYMENTS INC' 'AMAZON MECHANICAL TURK INC'
#  'AMAZON WEB SERVICES INC' 'AMAZON. COM SEVS INC' 'AMAZON FRESH LLC'
#  'AMAZON STUDIOS LLC' 'AMAZON MEDIA GROUP LLC' 'AMAZON MEDIA GROUP'
#  'AMAZON CAPITAL SERVICES INC' 'AMAZON REGISTRY SERVICES INC'
#  'AMAZON RESTAURANT & BAR INC' 'AMAZON ROBOTICS LLC' 'AMAZON SERVICES LLC'
#  'AMAZON FULFILLMENT SERVICES INC' 'AMAZON COM SVCS INC'
#  'AMAZON DIGITAL SVCS INC' 'AMAZON COM SERVICES INC'
#  'AMAZON FULFILLMENT SVCS INC' 'AMAZON COM SERVICES INC FORMERLY K'
#  'AMAZON DIGITAL SERVICES INC' 'AMAZON COM INDC LLC' 'AMAZON COM KSDC LLC'
#  'AMAZON.COM KYDC LLC' 'AMAZON.COM.DEDC LLC' 'AMAZON TECHNOLOGIES INC'
#  'AMAZON.COM SERVICES SERVICES INC' 'AMAZON.COM SERVICES INC'
#  'AMAZON COM KYDC LLC' 'AMAZON COM DEDC LLC' 'AMAZON COM AZDC INC'
#  'AMAZON WEB SERVICES LLC' 'AMAZON PRODUCE NETWORK LLC'
#  'AMAZON PROFESSINAL CARE' 'AMAZON SOCIETY INC' 'AMAZON.COM.NVDC INC'
#  'AMAZON.COM KYDC INC' 'AMAZON GLOBAL RESOURCES INC' 'AMAZON WATCH'
#  'AMAZON PRODUCE NETWORK LLP' 'AMAZON COM NVDC INC' 'AMAZON SVCS LLC'
#  'AMAZON.COM.KYDC INC' 'AMAZON.COM DEDC LLC' 'AMAZON CARGO INC'
#  'AMAZON LOGISTICS GROUP LLC' 'AMAZON.COM.KYDC LLC' 'AMAZON MASONRY INC'
#  'AMAZON WEB SREVICES INC' 'AMAZON PHARMACY INC' 'AMAZON CAPITAL SVCS INC'
#  'A2Z DVLP CTR INC DBA AMAZON MUSIC' 'AMAZON CORP LLC'
#  'AMAZON.COM.AZDC LLC' 'AMAZON RESTAURANT AND BAR INC'
#  'AMAZON STUDIOS INC' 'AMAZON.COM.INDC LLC']

# %% [markdown]
# ##### Another example DELOITTE uses variery of names to file based on there subcidiary, But they all come under DELOITTE so replacing them with DELOITTE for analysis makes sense

# %%
pattern = r"\bDELOITTE\b\s*.*"
amazon= data[data['Employer'].str.contains(pattern, na=False)]['Employer']
print(amazon.unique())
# Out:
# ['DELOITTE CONSULTING OVERS' 'DELOITTE FINANCIAL ADVISORY SERVIC'
#  'DELOITTE FIN ADVISORY SERVICES LLP' 'DELOITTE CONSULTING LLP'
#  'DELOITTE & TOUCHE LLP' 'DELOITTE TOUCHE TOHMATSU SVCS INC'
#  'DELOITTE TOUCHE TOHMATSU SVCS IN' 'DELOITTE TRANSACTIONS & BUS ANALYT'
#  'DELOITTE SERVICES LP' 'DELOITTE LLP' 'DELOITTE CORPORATE FINANCE LLC'
#  'DELOITTE TAX LLP' 'DELOITTE TRANSACTION & BUS ANALYTI'
#  'DELOITTE FIN ADVISORY SVCS LLP' 'DELOITTE TOUCHE TOHMATSU SERVICES'
#  'DELOITTE SVCS LP' 'DELOITTE LLP-DELOITTE LLP'
#  'DELOITTE FINANCIAL ADVISORY SVCS' 'DELOITTE CONSULTING OVERSEAS'
#  'DELOITTE CONSULTING OVERSEAS SVCS' 'DELOITTE & TOUCHE OVERSEAS SVCS LL'
#  'DELOITTE CONSULTING' 'DELOITTE CONSULTING EXTENDED B'
#  'DELOITTE TOUCHE OVERSEAS PROJECTS' 'DELOITTE FINANCIAL ADVISORY SRVCS'
#  'DELOITTE FINANCIAL ADVISORY SVCS L' 'DELOITTE CONS OVERSEAS PROJECTS LL'
#  'DELOITTE ANALYTICS LLC' 'DELOITTE & TOUCHE OVERSEAS PROJECT'
#  'DELOITTE & TOUCHE USA OVERSEAS SVC' 'DELOITTE CONSULTING EXTENDED'
#  'DELOITTE & TOUCHE LLC' 'DELOITTE TAX OVERSEAS SERVICES LLC'
#  'DELOITTE CONSULTING OVERSEAS PROJE' 'DELOITTE MARKETPOINT LLC'
#  'DELOITTE TAX OVERSEAS SVCS LLC' 'DELOITTE SERVICES LLP'
#  'DELOITTE SVCS OVERSEAS SVCS LLC' 'DELOITTE CORP FINANCE LLC'
#  'DELOITTE TOUCHE LLP' 'DELOITTE COSULTING LLP'
#  'DELOITTE CONS OVERSEAS PROJECT LLC' 'DELOITTE TRANSACTIONS AND BUSINESS']

# %% [markdown]
# ### TOP EMPLOYERS BY COUNT OF SUM OF INITIAL APPROVALS

# %%
top_employers_by_approvals= data.pivot_table(values=['Initial Approvals'], index='Employer', aggfunc=[np.sum] ,margins=False)
top_employers_by_approvals=top_employers_by_approvals.reset_index()

# %%
top_employers_by_approvals.columns
# Out:
# MultiIndex(levels=[['sum', 'Employer'], ['Initial Approvals', '']],
#            codes=[[1, 0], [1, 0]])

# %%
top_employers_by_approvals= top_employers_by_approvals.sort_values(by=[('sum','Initial Approvals')], ascending=False)
top_employers_by_approvals.head()
# Out:
#                           Employer               sum
#                                    Initial Approvals
# 119050           INTEL CORPORATION            5540.0
# 112945   IBM INDIA PRIVATE LIMITED            5248.0
# 12993         AMAZON CORPORATE LLC            4160.0
# 189927  PRICEWATERHOUSECOOPERS LLP            4012.0
# 160920         MPHASIS CORPORATION            3347.0

# %% [markdown]
# #### CLEANING EMPLOYER NAME BY REPLACING IT WITH ONE SHORT-CODE FOR MOST COMMON EMPLOYERS

# %%
#approvals['short_code'] = approvals['Employer'].apply(lambda x: x.split(' ')[0])
top_employers_by_approvals['short_code'] = top_employers_by_approvals['Employer'].str.split().str.get(0)

# %%
top_employers_by_approvals.head(20)
# Out:
#                                 Employer               sum  \
#                                          Initial Approvals
# 119050                 INTEL CORPORATION            5540.0
# 112945         IBM INDIA PRIVATE LIMITED            5248.0
# 12993               AMAZON CORPORATE LLC            4160.0
# 189927        PRICEWATERHOUSECOOPERS LLP            4012.0
# 160920               MPHASIS CORPORATION            3347.0
# 83792                       FACEBOOK INC            3207.0
# 99062                         GOOGLE INC            3163.0
# 254622                    UST GLOBAL INC            2956.0
# 176830                ORACLE AMERICA INC            2728.0
# 65838              DELOITTE & TOUCHE LLP            2638.0
# 112939                   IBM CORPORATION            2516.0
# 65848            DELOITTE CONSULTING LLP            2506.0
# 233656        TECH MAHINDRA AMERICAS INC            2464.0
# 157164                  MINDTREE LIMITED            2416.0
# 137146  LARSEN & TOUBRO INFOTECH LIMITED            2401.0
# 98658                 GOLDMAN SACHS & CO            2195.0
# 61427                        CUMMINS INC            2076.0
# 134371                          KPMG LLP            2042.0
# 18127                          APPLE INC            2034.0
# 194123         QUALCOMM TECHNOLOGIES INC            2015.0
#
#                     short_code
#
# 119050                   INTEL
# 112945                     IBM
# 12993                   AMAZON
# 189927  PRICEWATERHOUSECOOPERS
# 160920                 MPHASIS
# 83792                 FACEBOOK
# 99062                   GOOGLE
# 254622                     UST
# 176830                  ORACLE
# 65838                 DELOITTE
# 112939                     IBM
# 65848                 DELOITTE
# 233656                    TECH
# 157164                MINDTREE
# 137146                  LARSEN
# 98658                  GOLDMAN
# 61427                  CUMMINS
# 134371                    KPMG
# 18127                    APPLE
# 194123                QUALCOMM

# %%
len(top_employers_by_approvals['Employer'].unique())
# Out:
# 271494

# %%
top_100_employers_by_approvals= top_employers_by_approvals.head(300)
top_100_employers_by_approvals_list = top_100_employers_by_approvals['short_code'].unique()
top_100_employers_by_approvals_list = [e for e in  top_100_employers_by_approvals_list if e not in ('COMPUTER', 'CSC','RITE','TECH', 'UNIV', 'UST','THE','BANK','NEW')]
top_100_employers_by_approvals_list
# Out:
# ['INTEL',
#  'IBM',
#  'AMAZON',
#  'PRICEWATERHOUSECOOPERS',
#  'MPHASIS',
#  'FACEBOOK',
#  'GOOGLE',
#  'ORACLE',
#  'DELOITTE',
#  'MINDTREE',
#  'LARSEN',
#  'GOLDMAN',
#  'CUMMINS',
#  'KPMG',
#  'APPLE',
#  'QUALCOMM',
#  'IGATE',
#  'SYNECHRON',
#  'HEXAWARE',
#  'SYNTEL',
#  'CAPGEMINI',
#  'PATNI',
#  'CISCO',
#  'JPMORGAN',
#  'ERNST',
#  'YAHOO',
#  'KPIT',
#  'NVIDIA',
#  'EBAY',
#  'UNIVERSITY',
#  'VMWARE',
#  'EMC',
#  'ACCENTURE',
#  'BAYLOR',
#  'MARLABS',
#  'BIRLASOFT',
#  'MCKINSEY',
#  'NTT',
#  'WAL-MART',
#  'KFORCE',
#  'BLOOMBERG',
#  'BROADCOM',
#  'PAYPAL',
#  'ZENSAR',
#  'ERICSSON',
#  'POPULUS',
#  'CERNER',
#  'LINKEDIN',
#  'EPIC',
#  'TATA',
#  'STANFORD',
#  'INFOTECH',
#  'POLARIS',
#  'TEXAS',
#  'PERSISTENT',
#  'MAYO',
#  'COLUMBIA',
#  'YALE',
#  'MARVELL',
#  'CLEVELAND',
#  'HTC',
#  'HARVARD',
#  'VIRTUSA',
#  'NIIT',
#  'MICROSOFT',
#  'ADVANCED',
#  'COGNIZANT',
#  'NETAPP',
#  'JUNIPER',
#  'EMORY',
#  'SCHLUMBERGER',
#  'ADOBE',
#  'YAHOO!',
#  'GLOBALFOUNDRIES',
#  'CITIGROUP',
#  'HEADSTRONG',
#  'WASHINGTON',
#  'DELL',
#  'CREDIT',
#  'HITACHI',
#  'MICRON',
#  'EPAM',
#  'ZS',
#  'APPLIED',
#  'CGI',
#  'UBER',
#  'EXPERIS',
#  'TESLA',
#  'HOWARD',
#  'RELIABLE',
#  'AMAZON.COM',
#  'INTUIT',
#  'DUKE',
#  'GENERAL',
#  'NESS',
#  'JOHNS',
#  'SYNOPSYS',
#  'L&T',
#  'SALESFORCE.COM',
#  'CITIBANK',
#  'NATSOFT',
#  'ECLINICALWORKS',
#  'SATYAM',
#  'SYMANTEC',
#  'NORTHWESTERN',
#  'SAP',
#  'HEWLETT-PACKARD',
#  'MEMORIAL',
#  'BARCLAYS',
#  'FIDELITY',
#  'FUJITSU',
#  'KEANE',
#  'ALCATEL-LUCENT',
#  'CIBER',
#  'MERRILL',
#  'HCL',
#  'CAPITAL',
#  'NYU',
#  'DIS/NATL',
#  'DEUTSCHE',
#  'SMARTPLAY',
#  'UT',
#  'AMDOCS',
#  'MICHIGAN',
#  'DANA',
#  'GRANDISON',
#  'YASH',
#  'EXPEDIA',
#  'COLLABERA',
#  'TWITTER',
#  'RUTGERS',
#  'AVCO',
#  'SLK',
#  'AMERICAN',
#  'BLACKROCK',
#  'MEDTRONIC',
#  'ALBERT',
#  'MORGAN',
#  '3I',
#  'CADENCE',
#  'DALLAS',
#  'ITC',
#  'MOTOROLA',
#  'DIASPARK',
#  'NAGARRO',
#  'ORION',
#  'UCHICAGO',
#  'ZYLOG',
#  'AKAMAI',
#  'CITRIX',
#  'CITIUSTECH',
#  'AMGEN',
#  'WIPRO',
#  'VANDERBILT',
#  'SAPIENT',
#  'OAK',
#  'CMC',
#  'TAVANT',
#  'SAMSUNG',
#  'CFA',
#  'GENPACT',
#  'CASE',
#  'GROUPON',
#  'DIS/NATIONAL',
#  'GEOMETRIC',
#  'MANHATTAN',
#  'BRILLIO',
#  'INDIANA',
#  'PHOTON',
#  'TERADATA',
#  'ARIZONA',
#  'MOUNT',
#  'COLLABORATE',
#  'HUGHES',
#  'UHCP',
#  'TIBCO',
#  'BAIN',
#  'INFOSYS',
#  'SYSTEM',
#  'GENENTECH',
#  'PFIZER',
#  'INTONE',
#  'FACTSET',
#  'UBS',
#  'GEORGIA',
#  'BROCADE',
#  'ELECTRONIC',
#  'BATTELLE',
#  'FREESCALE',
#  'ASTIR',
#  'WESTERN',
#  'XORIANT',
#  'V-SOFT',
#  'MINDLANCE',
#  'MU',
#  'INOVANT',
#  'CYIENT',
#  'CALIFORNIA',
#  'BAKER',
#  'HENRY',
#  'CORNELL']

# %% [markdown]
# ### USING PANDAS VECTORIZED FUNCTIONS CLEANING EMPLOYERS NAME

# %%
for employer in top_100_employers_by_approvals_list:
    pattern= r"\b{}\b\s*.*".format(employer)
    data['Employer'].str.replace(pattern, employer)

# %%
pattern = r"\bAMAZON\b\s*.*"
amazon= data[data['Employer'].str.contains(pattern, na=False)]['Employer']
print(amazon.unique())
# Out:
# ['AMAZON' 'A2Z DVLP CTR INC DBA AMAZON']

# %%
pattern = r"\bDELOITTE\b\s*.*"
amazon= data[data['Employer'].str.contains(pattern, na=False)]['Employer']
print(amazon.unique())
# Out:
# ['DELOITTE']

# %%
len(data['Employer'].unique())
# Out:
# 268240

# %% [markdown]
# ### WHAT ARE THE DIFFERENT NAICS CODES MEAN?

# %%
naics = pd.read_csv("/Users/ankitkothari/Documents/COMPLETED_PROJECTS/H1B_data_analysis/naics.csv")
naics['Sector']=naics['Sector'].astype(int)
print(naics.head())
print(data['NAICS'].head())

us_h1b_data = data.merge(naics, left_on='NAICS', right_on='Sector', how='left')
us_h1b_data.rename(columns={'Initial Approvals':'Initial_Approvals', 'Initial Denials':'Initial_Denials','Continuing Approvals':'Continuing_Approvals','Continuing Denials':'Continuing_Denials','Tax ID':'Tax_ID','Fiscal Year':'Fiscal_Year'}, inplace=True)
us_h1b_data.drop(['Sector','Name'], axis=1, inplace=True)
# Out:
#    Sector                                           Name
# 0      11     Agriculture, Forestry, Fishing and Hunting
# 1      21  Mining, Quarrying, and Oil and Gas Extraction
# 2      22                                      Utilities
# 3      23                                   Construction
# 4      31                                  Manufacturing
# 0    99
# 1    33
# 2    33
# 3    33
# 4    52
# Name: NAICS, dtype: int64

# %%
us_h1b_data.head()
# Out:
#    Fiscal_Year                     Employer  Initial_Approvals  \
# 0         2018          REDDY GI ASSOCIATES                0.0
# 1         2018      ADMIRAL INSTRUMENTS LLC                1.0
# 2         2018      THE BELPORT COMPANY INC                0.0
# 3         2018  CALLAWAY GOLF SALES COMPANY                1.0
# 4         2018          PAYSAFE PARTNERS LP                0.0
#
#    Initial_Denials  Continuing_Approvals  Continuing_Denials  NAICS State  \
# 0              0.0                   0.0                 1.0     99    AZ
# 1              0.0                   0.0                 0.0     33    AZ
# 2              1.0                   0.0                 0.0     33    CA
# 3              0.0                   0.0                 0.0     33    CA
# 4              0.0                   1.0                 0.0     52    CA
#
#         City      ZIP        long       lang
# 0       MESA  85209.0 -111.093731  34.048928
# 1      TEMPE  85281.0 -111.093731  34.048928
# 2  CAMARILLO  93012.0 -119.417932  36.778261
# 3   CARLSBAD  92008.0 -119.417932  36.778261
# 4     IRVINE  92612.0 -119.417932  36.778261

# %% [markdown]
# ### EXPORTING THIS DATA TO A SQLITE3 DATABASE

# %%
db= "us_h1b.db"
def run_query(q):
      with sqlite3.connect(db) as conn:
          return pd.read_sql(q,conn)

def run_command(c):
      with sqlite3.connect(db) as conn:
          conn.execute('PRAGMA foreign_keys = ON;')
          conn.isolation_level = None
          conn.execute(c)

def show_tables():
      q = '''
      SELECT
          name,
          type
      FROM sqlite_master
      WHERE type IN ("table","view");
      '''
      return run_query(q)

c2 = '''CREATE TABLE IF NOT EXISTS h1b (
      id INTEGER PRIMARY KEY AUTOINCREMENT,
      Fiscal_Year datetime,
      Employer text,
      Initial_Approvals INT,
      Initial_Denials int,
      Continuing_Approvals int,
      Continuing_Denials int,
      NAICS int,
      Tax_ID float,
      State  text,
      City  text,
      ZIP  int,
      long  float,
      lang  float
  ); '''

run_command(c2)

print(show_tables())

with sqlite3.connect(db) as conn:
       us_h1b_data.to_sql('h1b', conn, if_exists= 'append', index= False)
# Out:
#               name   type
# 0              h1b  table
# 1  sqlite_sequence  table

# %% [markdown]
# ### Next Steps: Part 3: Using this data writing queries to analyze important H1B trends from 2009 to 2018
