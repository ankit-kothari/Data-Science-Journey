# %%
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# ### Loading the Data

# %%
data = pd.read_csv('./newCarsIndia.csv')
data.sample(5)
# Out:
#                             Car                   Style               Range  \
# 54                     MG ZS EV             Compact SUV  419 Km/Full Charge
# 127                    Audi RS5    Premium Sports Coupe           11.1 Km/l
# 239         Mercedes-AMG GLS 63    Premium Fullsize SUV            8.5 Km/l
# 151       Mercedes-Benz E-Class  Premium Fullsize Sedan   12.06 - 14.2 Km/l
# 196  Volkswagen Tiguan AllSpace                     SUV             11 Km/l
#
#     Transmission    VehicleType         PriceRange Rating(outof10)
# 54     Automatic       Electric  ₹ 21.99 - 25.88 L             8.2
# 127    Automatic         Petrol          ₹ 1.09 Cr             7.1
# 239    Automatic         Petrol          ₹ 1.57 Cr             7.6
# 151    Automatic  Petrol,Diesel        ₹ 67 - 85 L             7.8
# 196    Automatic         Petrol           ₹ 34.2 L             8.3

# %% [markdown]
# #### Size of Data

# %%
data.shape
# Out:
# (255, 9)

# %% [markdown]
# #### Unique Cars

# %%
data['Car'].nunique()
# Out:
# 255

# %% [markdown]
# #### Checking Null Values in The Data

# %%
data.isnull().sum()
# Out:
# Car                 0
# Style               0
# Range              11
# Transmission        0
# VehicleType         0
# PriceRange          0
# Rating(outof10)     0
# Make                0
# max_range          11
# dtype: int64

# %% [markdown]
# ### Data Cleaning and Analysis

# %% [markdown]
# #### Creating a column for Make of the Car

# %% [markdown]
# - Replacing car brands with two or more words eg Maruti Suzuki  with '-' instead of space, so they can be cleanly seperated.

# %%
data['Car'] = data['Car'].str.lower()
data['Car'] = data['Car'].str.replace('maruti suzuki',
                                      'maruti-suzuki').str.replace(
                                          'aston martin',
                                          'aston-martin').str.replace(
                                              'land rover', 'land-rover')
data['Make'] = data['Car'].str.split(' ').str.get(0)

# %%
data['Make'].unique()
# Out:
# array(['tata', 'hyundai', 'maruti-suzuki', 'mg', 'kia', 'mahindra',
#        'toyota', 'honda', 'volkswagen', 'audi', 'nissan', 'skoda',
#        'renault', 'bmw', 'bajaj', 'mercedes-benz', 'jeep', 'mercedes-amg',
#        'datsun', 'rolls-royce', 'ford', 'isuzu', 'land-rover', 'jaguar',
#        'lexus', 'force', 'volvo', 'lamborghini', 'citroen', 'ferrari',
#        'mini', 'mercedes-maybach', 'porsche', 'aston-martin', 'bentley',
#        'maserati', 'byd', 'ssangyong'], dtype=object)

# %%
data.sample(3)
# Out:
#                        Car                  Style               Range  \
# 31                 audi q7   Premium Fullsize SUV                 NaN
# 104          jaguar i-pace  Premium Midsize Sedan  470 Km/Full Charge
# 238  maserati quattroporte   Premium Luxury Sedan     7.9 - 10.7 Km/l
#
#     Transmission    VehicleType        PriceRange Rating(outof10)      Make
# 31     Automatic         Petrol  ₹ 82.49 - 89.9 L             8.4      audi
# 104    Automatic       Electric  ₹ 1.06 - 1.12 Cr              na    jaguar
# 238    Automatic  Petrol,Diesel  ₹ 1.63 - 2.51 Cr             7.6  maserati

# %% [markdown]
# #### Creating a Column for Max Range of a Car

# %% [markdown]
# - Using extractall, extracting all the numeric values in the Range column
# - Using Unstack making them columns instead of rows
# - Selecting the max value among them as "max_range"

# %%
pattern = r"([0-9]+.[0-9]*)"
data['max_range'] = data['Range'].str.extractall(pattern).unstack().astype(
    float).max(axis=1)

# %%
data.sample(5)
# Out:
#                               Car                 Style               Range  \
# 105                       audi q5   Premium Midsize SUV           13.5 Km/l
# 110  land-rover range rover velar                   SUV     9.2 - 16.6 Km/l
# 149                  bmw 7 series  Premium Luxury Sedan  11.86 - 39.53 Km/l
# 101           citroen c5 aircross           Compact SUV           18.6 Km/l
# 102           lamborghini huracan       Supersports Car   10.3 - 11.91 Km/l
#
#     Transmission           VehicleType         PriceRange Rating(outof10)  \
# 105    Automatic                Petrol   ₹ 59.9 - 65.55 L             7.5
# 110    Automatic         Petrol,Diesel  ₹ 79.87 - 80.71 L              na
# 149    Automatic  Diesel,Petrol,Hybrid   ₹ 1.42 - 1.76 Cr             7.7
# 101    Automatic                Diesel    ₹ 31.3 - 32.8 L              na
# 102    Automatic                Petrol    ₹ 3.22 - 4.1 Cr             8.5
#
#             Make  max_range
# 105         audi      13.50
# 110   land-rover      16.60
# 149          bmw      39.53
# 101      citroen      18.60
# 102  lamborghini      11.91

# %% [markdown]
# #### Filtering Cars with max_range greater than 100

# %%
data.query('max_range>100')
# Out:
#                           Car                  Style               Range  \
# 0               tata nexon ev            Compact SUV  312 Km/Full Charge
# 32              tata tigor ev       Subcompact Sedan  306 Km/Full Charge
# 52          tata nexon ev max            Compact SUV  437 Km/Full Charge
# 54                   mg zs ev            Compact SUV  419 Km/Full Charge
# 71      hyundai kona electric            Compact SUV  452 Km/Full Charge
# 104             jaguar i-pace  Premium Midsize Sedan  470 Km/Full Charge
# 113            audi e-tron gt          Premium Coupe  388 Km/Full Charge
# 170                    byd e6         Subcompact MPV  415 Km/Full Charge
# 177         mercedes-benz eqc            Compact SUV  471 Km/Full Charge
# 192                    bmw ix   Premium Fullsize SUV  425 Km/Full Charge
# 217               audi e-tron            Compact SUV  400 Km/Full Charge
# 240  audi e-tron gt sportback    Premium Midsize SUV  388 Km/Full Charge
# 245         audi rs e-tron gt    Premium Midsize SUV  401 Km/Full Charge
# 254                   mini se       Luxury Hatchback  270 Km/Full Charge
#
#     Transmission VehicleType         PriceRange Rating(outof10)  \
# 0      Automatic    Electric   ₹ 13.99 - 17.4 L             8.5
# 32     Automatic    Electric  ₹ 12.49 - 13.64 L              na
# 52     Automatic    Electric  ₹ 17.74 - 19.24 L              na
# 54     Automatic    Electric  ₹ 21.99 - 25.88 L             8.2
# 71     Automatic    Electric  ₹ 23.79 - 23.98 L             8.7
# 104    Automatic    Electric   ₹ 1.06 - 1.12 Cr              na
# 113    Automatic    Electric           ₹ 1.8 Cr              na
# 170    Automatic    Electric          ₹ 29.15 L              na
# 177    Automatic    Electric             ₹ 1 Cr             8.2
# 192    Automatic    Electric          ₹ 1.16 Cr              na
# 217    Automatic    Electric   ₹ 1.01 - 1.19 Cr              na
# 240    Automatic    Electric           ₹ 1.8 Cr              na
# 245    Automatic    Electric          ₹ 2.05 Cr              na
# 254    Automatic    Electric           ₹ 47.2 L              na
#
#               Make  max_range   max_price
# 0             tata      312.0   1740000.0
# 32            tata      306.0   1364000.0
# 52            tata      437.0   1924000.0
# 54              mg      419.0   2588000.0
# 71         hyundai      452.0   2398000.0
# 104         jaguar      470.0  11200000.0
# 113           audi      388.0  18000000.0
# 170            byd      415.0   2915000.0
# 177  mercedes-benz      471.0  10000000.0
# 192            bmw      425.0  11600000.0
# 217           audi      400.0  11900000.0
# 240           audi      388.0  18000000.0
# 245           audi      401.0  20500000.0
# 254           mini      270.0   4720000.0

# %% [markdown]
# #### Cleaning, Extracting and Convering in the Max Price into Indian Rupee

# %% [markdown]
# - Replacing '₹' with a space
# - Converting lakh 'L' by multiplying 10^5 and 'Cr' with 10^7
# - Doing it in the same dataframe by creating specific filters

# %%
data['max_price'] = data['PriceRange'].str.split('-').str.get(-1).str.replace('₹','')

# %%
data['max_price'].isnull().sum()
# Out:
# 0

# %%
lakh_filter = data['max_price'].str.contains('L')
crore_filter = data['max_price'].str.contains('Cr')

# %%
data.loc[lakh_filter, 'max_price'] = data.loc[lakh_filter, 'max_price'].apply(
    lambda x: float(x.split(' ')[1]) * 100000)
data.loc[crore_filter,
         'max_price'] = data.loc[crore_filter, 'max_price'].apply(
             lambda x: float(x.split(' ')[1]) * 10000000)

# %%
data.sample(3)
# Out:
#                    Car              Style               Range  \
# 17   hyundai elite i20  Premium Hatchback    18.6 - 25.2 Km/l
# 210       ferrari roma         Sports Car            5.8 Km/l
# 14       toyota glanza  Premium Hatchback  22.35 - 22.94 Km/l
#
#              Transmission    VehicleType        PriceRange Rating(outof10)  \
# 17   AMT,Automatic,Manual  Petrol,Diesel  ₹ 6.98 - 11.47 L             8.2
# 210                Manual         Petrol         ₹ 3.61 Cr              na
# 14             AMT,Manual         Petrol   ₹ 6.39 - 9.69 L             7.7
#
#         Make  max_range   max_price
# 17   hyundai      25.20   1147000.0
# 210  ferrari       5.80  36100000.0
# 14    toyota      22.94    969000.0

# %% [markdown]
# #### Top Cars by Style

# %% [markdown]
# - The Goal is to Identify top 5% Cars by Price in each of the Style Segment eg: SUV, Compact Sedan
#     - Calculate the 95th percentile
#     - Using Transform Function, make a new column and add it as a value.
#     - Filter cars where "max_price" > 95th percentile value.

# %%
data['percentile_by_style'] = data.groupby(
    ['Style'])['max_price'].transform(lambda x: x.quantile(.95))

# %%
data.sample(4)
# Out:
#                         Car           Style             Range  \
# 114    land-rover discovery      Luxury SUV          9.2 Km/l
# 33           nissan magnite  Subcompact SUV    17.7 - 20 Km/l
# 27               honda city   Compact Sedan  17.8 - 24.1 Km/l
# 69   land-rover range rover      Luxury SUV   7.5 - 12.8 Km/l
#
#          Transmission           VehicleType           PriceRange  \
# 114         Automatic         Petrol,Diesel  ₹ 88.06 L - 1.26 Cr
# 33   Automatic,Manual                Petrol        ₹ 5.59 - 10 L
# 27   Automatic,Manual  Petrol,Diesel,Hybrid     ₹ 11.29 - 19.5 L
# 69          Automatic         Diesel,Petrol     ₹ 2.32 - 3.41 Cr
#
#     Rating(outof10)        Make  max_range   max_price  percentile_by_style
# 114             7.9  land-rover        9.2  12600000.0           47800000.0
# 33               na      nissan       20.0   1000000.0            1390500.0
# 27              8.2       honda       24.1   1950000.0            1826100.0
# 69              7.7  land-rover       12.8  34100000.0           47800000.0

# %%
data.query('percentile_by_style<max_price').sort_values(by='Style')
# Out:
#                                    Car                   Style  \
# 60                 maruti-suzuki swift       Compact Hatchback
# 66                    mahindra marazzo             Compact MPV
# 217                        audi e-tron             Compact SUV
# 116  mercedes-benz e-class all-terrain   Compact SUV/Crossover
# 27                          honda city           Compact Sedan
# 29                          tata tiago         Entry Hatchback
# 154                       toyota camry          Fullsize Sedan
# 203              mercedes-benz v-class    Fullsize/Premium MPV
# 117                  mercedes-amg a 45        Luxury Hatchback
# 197               rolls-royce cullinan              Luxury SUV
# 92                       skoda octavia           Midsize Sedan
# 153                 audi rs7 sportback       Performance Sedan
# 139                      porsche macan     Premium Compact SUV
# 159                mercedes-amg cla 45   Premium Compact Sedan
# 226                   rolls-royce dawn           Premium Coupe
# 100                   lamborghini urus    Premium Fullsize SUV
# 205                           lexus ls  Premium Fullsize Sedan
# 227                 hyundai i20 n line       Premium Hatchback
# 65                 rolls-royce phantom    Premium Luxury Sedan
# 245                  audi rs e-tron gt     Premium Midsize SUV
# 150                mercedes-amg c 63 s   Premium Midsize Sedan
# 242                   aston-martin dbx    Premium Sports Sedan
# 118                land-rover defender                     SUV
# 110       land-rover range rover velar                     SUV
# 236              ferrari sf90 stradale              Sports Car
# 170                             byd e6          Subcompact MPV
# 25                     mahindra xuv300          Subcompact SUV
# 32                       tata tigor ev        Subcompact Sedan
# 136              lamborghini aventador         Supersports Car
#
#                   Range      Transmission           VehicleType  \
# 60              22 Km/l        AMT,Manual                Petrol
# 66            17.6 Km/l            Manual                Diesel
# 217  400 Km/Full Charge         Automatic              Electric
# 116           12.1 Km/l         Automatic                Diesel
# 27     17.8 - 24.1 Km/l  Automatic,Manual  Petrol,Diesel,Hybrid
# 29           23.84 Km/l        AMT,Manual     Petrol,Petrol+CNG
# 154          19.16 Km/l         Automatic                Hybrid
# 203             16 Km/l         Automatic                Diesel
# 117                 NaN         Automatic                Petrol
# 197              7 Km/l         Automatic                Petrol
# 92           15.81 Km/l         Automatic                Petrol
# 153           11.6 Km/l         Automatic                Petrol
# 139           13.2 Km/l         Automatic                Petrol
# 159             15 Km/l         Automatic                Petrol
# 226           14.4 Km/l         Automatic                Petrol
# 100            7.8 Km/l         Automatic                Petrol
# 205           15.4 Km/l         Automatic                Petrol
# 227          20.25 Km/l  Automatic,Manual                Petrol
# 65             7.2 Km/l         Automatic                Petrol
# 245  401 Km/Full Charge         Automatic              Electric
# 150          14.49 Km/l         Automatic                Petrol
# 242             12 Km/l         Automatic                Diesel
# 118      8.62 - 14 Km/l         Automatic         Petrol,Diesel
# 110     9.2 - 16.6 Km/l         Automatic         Petrol,Diesel
# 236             18 Km/l         Automatic                Petrol
# 170  415 Km/Full Charge         Automatic              Electric
# 25         17 - 20 Km/l        AMT,Manual         Petrol,Diesel
# 32   306 Km/Full Charge         Automatic              Electric
# 136             16 Km/l         Automatic                Petrol
#
#               PriceRange Rating(outof10)           Make  max_range  \
# 60       ₹ 5.92 - 8.85 L             8.0  maruti-suzuki      22.00
# 66     ₹ 12.42 - 14.57 L             8.3       mahindra      17.60
# 217     ₹ 1.01 - 1.19 Cr              na           audi     400.00
# 116            ₹ 77.25 L              na  mercedes-benz      12.10
# 27      ₹ 11.29 - 19.5 L             8.2          honda      24.10
# 29       ₹ 5.38 - 7.53 L             8.2           tata      23.84
# 154            ₹ 43.45 L             7.4         toyota      19.16
# 203    ₹ 71.1 L - 1.1 Cr             7.9  mercedes-benz      16.00
# 117             ₹ 81.5 L              na   mercedes-amg        NaN
# 197            ₹ 6.95 Cr              na    rolls-royce       7.00
# 92     ₹ 26.29 - 29.29 L             8.4          skoda      15.81
# 153            ₹ 2.24 Cr             8.1           audi      11.60
# 139            ₹ 83.21 L             6.5        porsche      13.20
# 159    ₹ 77.69 - 77.85 L             6.8   mercedes-amg      15.00
# 226            ₹ 5.92 Cr              na    rolls-royce      14.40
# 100               ₹ 3 Cr             8.6    lamborghini       7.80
# 205     ₹ 1.91 - 2.22 Cr             7.9          lexus      15.40
# 227     ₹ 9.91 - 11.97 L              na        hyundai      20.25
# 65      ₹ 9.5 - 11.35 Cr             7.1    rolls-royce       7.20
# 245            ₹ 2.05 Cr              na           audi     401.00
# 150            ₹ 1.33 Cr             6.9   mercedes-amg      14.49
# 242            ₹ 3.82 Cr              na   aston-martin      12.00
# 118  ₹ 76.57 L - 1.12 Cr              na     land-rover      14.00
# 110    ₹ 79.87 - 80.71 L              na     land-rover      16.60
# 236             ₹ 7.5 Cr              na        ferrari      18.00
# 170            ₹ 29.15 L              na            byd     415.00
# 25      ₹ 8.41 - 14.07 L             8.4       mahindra      20.00
# 32     ₹ 12.49 - 13.64 L              na           tata     306.00
# 136     ₹ 4.79 - 5.32 Cr             8.0    lamborghini      16.00
#
#        max_price  percentile_by_style
# 60      885000.0             876500.0
# 66     1457000.0            1439200.0
# 217   11900000.0           10190000.0
# 116    7725000.0            7217250.0
# 27     1950000.0            1826100.0
# 29      753000.0             744000.0
# 154    4345000.0            4307000.0
# 203   11000000.0           10616000.0
# 117    8150000.0            7445000.0
# 197   69500000.0           47800000.0
# 92     2929000.0            2888200.0
# 153   22400000.0           21900000.0
# 139    8321000.0            8154900.0
# 159    7785000.0            7580700.0
# 226   59200000.0           42600000.0
# 100   30000000.0           24870000.0
# 205   22200000.0           20400000.0
# 227    1197000.0            1179500.0
# 65   113500000.0           96500000.0
# 245   20500000.0           19500000.0
# 150   13300000.0           12040000.0
# 242   38200000.0           34030000.0
# 118   11200000.0            7797700.0
# 110    8071000.0            7797700.0
# 236   75000000.0           55860000.0
# 170    2915000.0            2743250.0
# 25     1407000.0            1390500.0
# 32     1364000.0            1315600.0
# 136   53200000.0           52375000.0

# %% [markdown]
# #### Maximum Range of Cars by Make

# %%
data.columns
# Out:
# Index(['Car', 'Style', 'Range', 'Transmission', 'VehicleType', 'PriceRange',
#        'Rating(outof10)', 'Make', 'max_range', 'max_price',
#        'percentile_by_style'],
#       dtype='object')

# %%
petrol_filter = data['VehicleType'].str.contains('Petrol')
data.loc[data.loc[petrol_filter,:].groupby('Make')['max_range'].idxmax()][[
    'Make', 'Car', 'max_range', 'VehicleType'
]]
# Out:
#                  Make                           Car  max_range  \
# 143      aston-martin             aston-martin db11      12.00
# 106              audi                       audi a4      17.84
# 46              bajaj                    bajaj qute      43.00
# 234           bentley           bentley continental      10.60
# 149               bmw                  bmw 7 series      39.53
# 132            datsun                datsun redi go      22.00
# 236           ferrari         ferrari sf90 stradale      18.00
# 130              ford              ford figo aspire      24.40
# 168             honda                    honda wr-v      25.50
# 70            hyundai            hyundai new santro      30.48
# 107            jaguar                     jaguar xf      19.30
# 55               jeep                  jeep compass      16.97
# 48                kia                     kia sonet      24.10
# 136       lamborghini         lamborghini aventador      16.00
# 110        land-rover  land-rover range rover velar      16.60
# 129             lexus                    lexus rc f      16.10
# 25           mahindra               mahindra xuv300      20.00
# 10      maruti-suzuki         maruti-suzuki wagon r      33.40
# 163          maserati               maserati ghibli      16.94
# 193      mercedes-amg     mercedes-amg glc 43 coupe      16.35
# 56      mercedes-benz         mercedes-benz c-class      23.00
# 222  mercedes-maybach          mercedes-maybach gls       8.50
# 4                  mg                     mg hector      17.40
# 158              mini                   mini 3 door      17.33
# 33             nissan                nissan magnite      20.00
# 144           porsche               porsche boxster      14.40
# 43            renault                  renault kwid      25.00
# 207       rolls-royce             rolls-royce ghost      14.40
# 172             skoda                  skoda slavia      19.47
# 21               tata                   tata altroz      25.11
# 14             toyota                 toyota glanza      22.94
# 30         volkswagen             volkswagen taigun      18.47
# 181             volvo                     volvo s60      27.03
#
#               VehicleType
# 143                Petrol
# 106                Petrol
# 46      Petrol,Petrol+CNG
# 234                Petrol
# 149  Diesel,Petrol,Hybrid
# 132                Petrol
# 236                Petrol
# 130         Petrol,Diesel
# 168         Petrol,Diesel
# 70      Petrol,Petrol+CNG
# 107         Diesel,Petrol
# 55          Petrol,Diesel
# 48          Petrol,Diesel
# 136                Petrol
# 110         Petrol,Diesel
# 129                Petrol
# 25          Petrol,Diesel
# 10      Petrol,Petrol+CNG
# 163  Hybrid,Petrol,Diesel
# 193         Petrol,Diesel
# 56          Petrol,Diesel
# 222                Petrol
# 4    Petrol,Diesel,Hybrid
# 158                Petrol
# 33                 Petrol
# 144                Petrol
# 43                 Petrol
# 207                Petrol
# 172                Petrol
# 21          Petrol,Diesel
# 14                 Petrol
# 30                 Petrol
# 181                Petrol

# %% [markdown]
# #### Identify Maximum Range of Electric Cars by Make

# %%
electric_filter = data['VehicleType'].str.contains('Electric')
data.loc[data.loc[electric_filter, :].dropna(
    subset=['Range']).groupby('Make')['max_range'].idxmax()][[
        'Make', 'Car', 'max_range', 'VehicleType'
    ]]
# Out:
#               Make                    Car  max_range VehicleType
# 245           audi      audi rs e-tron gt      401.0    Electric
# 192            bmw                 bmw ix      425.0    Electric
# 170            byd                 byd e6      415.0    Electric
# 71         hyundai  hyundai kona electric      452.0    Electric
# 104         jaguar          jaguar i-pace      470.0    Electric
# 177  mercedes-benz      mercedes-benz eqc      471.0    Electric
# 54              mg               mg zs ev      419.0    Electric
# 254           mini                mini se      270.0    Electric
# 52            tata      tata nexon ev max      437.0    Electric

# %% [markdown]
# #### Most Expensive Cars by Make

# %%
data['max_price'] = data['max_price'].astype('float')
data.loc[data.groupby('Style')['max_price'].idxmax()][[
    'Style', 'Car', 'Make', 'max_price'
]].sort_values('Make').reset_index(drop=True)
# Out:
#                      Style                                Car           Make  \
# 0     Premium Sports Sedan                   aston-martin dbx   aston-martin
# 1              Compact SUV                        audi e-tron           audi
# 2      Premium Midsize SUV                  audi rs e-tron gt           audi
# 3        Performance Sedan                 audi rs7 sportback           audi
# 4              Quadricycle                         bajaj qute          bajaj
# 5           Subcompact MPV                             byd e6            byd
# 6               Sports Car              ferrari sf90 stradale        ferrari
# 7     Premium Sports Coupe                  ferrari gtc4lusso        ferrari
# 8            Compact Sedan                         honda city          honda
# 9        Premium Hatchback                 hyundai i20 n line        hyundai
# 10         Supersports Car              lamborghini aventador    lamborghini
# 11    Premium Fullsize SUV                   lamborghini urus    lamborghini
# 12                     SUV                land-rover defender     land-rover
# 13  Premium Fullsize Sedan                           lexus ls          lexus
# 14             Compact MPV                   mahindra marazzo       mahindra
# 15          Subcompact SUV                    mahindra xuv300       mahindra
# 16       Compact Hatchback                maruti-suzuki swift  maruti-suzuki
# 17   Premium Compact Sedan                mercedes-amg cla 45   mercedes-amg
# 18   Premium Midsize Sedan                mercedes-amg c 63 s   mercedes-amg
# 19        Luxury Hatchback                  mercedes-amg a 45   mercedes-amg
# 20    Fullsize/Premium MPV              mercedes-benz v-class  mercedes-benz
# 21   Compact SUV/Crossover  mercedes-benz e-class all-terrain  mercedes-benz
# 22             Midsize SUV                         mg gloster             mg
# 23     Premium Compact SUV                      porsche macan        porsche
# 24    Premium Luxury Sedan                rolls-royce phantom    rolls-royce
# 25              Luxury SUV               rolls-royce cullinan    rolls-royce
# 26           Premium Coupe                   rolls-royce dawn    rolls-royce
# 27           Midsize Sedan                      skoda octavia          skoda
# 28         Entry Hatchback                         tata tiago           tata
# 29        Subcompact Sedan                      tata tigor ev           tata
# 30          Fullsize Sedan                       toyota camry         toyota
#
#       max_price
# 0    38200000.0
# 1    11900000.0
# 2    20500000.0
# 3    22400000.0
# 4      284000.0
# 5     2915000.0
# 6    75000000.0
# 7    52000000.0
# 8     1950000.0
# 9     1197000.0
# 10   53200000.0
# 11   30000000.0
# 12   11200000.0
# 13   22200000.0
# 14    1457000.0
# 15    1407000.0
# 16     885000.0
# 17    7785000.0
# 18   13300000.0
# 19    8150000.0
# 20   11000000.0
# 21    7725000.0
# 22    3728000.0
# 23    8321000.0
# 24  113500000.0
# 25   69500000.0
# 26   59200000.0
# 27    2929000.0
# 28     753000.0
# 29    1364000.0
# 30    4345000.0

# %% [markdown]
# #### Percentage of Cars in different "Max Range" Segments

# %%
data.groupby(pd.cut(data['max_range'], [0, 10, 20, 30, 40, 100, 500])).agg({
    'Car':
    'count'
}).assign(pct_total=lambda x: round(x / x.sum() * 100))
# Out:
#             Car  pct_total
# max_range
# (0, 10]      34       14.0
# (10, 20]    147       60.0
# (20, 30]     41       17.0
# (30, 40]      5        2.0
# (40, 100]     3        1.0
# (100, 500]   14        6.0

# %% [markdown]
# #### Identifying Highest Rated Cars with only Manual Transmission

# %%
#Making the Transmission Column a List
data['Transmission']=data['Transmission'].str.split(',')

# %%
from sklearn.preprocessing import MultiLabelBinarizer
#To One Hot Encode the Transmission Column
mlb = MultiLabelBinarizer(sparse_output=True)
data = data.join(
            pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(data.pop('Transmission')),
                index=data.index,
                columns=mlb.classes_))

# %%
#Added Three New columns 'AMT','Automatic', 'Manual'
data.columns
# Out:
# Index(['Car', 'Style', 'Range', 'VehicleType', 'PriceRange', 'Rating(outof10)',
#        'Make', 'max_range', 'max_price', 'percentile_by_style', 'AMT',
#        'Automatic', 'Manual'],
#       dtype='object')

# %%
data.head(2)
# Out:
#                       Car              Style               Range  \
# 0           tata nexon ev        Compact SUV  312 Km/Full Charge
# 1  hyundai grand i10 nios  Compact Hatchback    20.2 - 26.2 Km/l
#
#                 VehicleType        PriceRange Rating(outof10)     Make  \
# 0                  Electric  ₹ 13.99 - 17.4 L             8.5     tata
# 1  Petrol,Petrol+CNG,Diesel    ₹ 5.3 - 8.51 L             8.5  hyundai
#
#    max_range  max_price  percentile_by_style  AMT  Automatic  Manual
# 0      312.0  1740000.0           10190000.0    0          1       0
# 1       26.2   851000.0             876500.0    1          0       1

# %%
#Looking at Ratings which has "na" string
na_rating_filter = data['Rating(outof10)']=='na'

# %%
data.loc[na_rating_filter,:].groupby(['Make']).size()
# Out:
# Make
# aston-martin        3
# audi                6
# bajaj               1
# bmw                 5
# byd                 1
# citroen             1
# ferrari             5
# hyundai             2
# jaguar              1
# kia                 2
# lamborghini         2
# land-rover          2
# lexus               2
# mahindra            6
# mercedes-amg        7
# mercedes-benz       3
# mercedes-maybach    2
# mg                  2
# mini                1
# nissan              1
# porsche             1
# renault             1
# rolls-royce         2
# skoda               2
# tata                4
# toyota              2
# volkswagen          1
# dtype: int64

# %%
data.loc[na_rating_filter,:].groupby(['Style']).size()
# Out:
# Style
# Compact SUV              8
# Compact SUV/Crossover    1
# Entry Hatchback          1
# Luxury Hatchback         3
# Luxury SUV               4
# Midsize SUV              1
# Premium Coupe            8
# Premium Fullsize SUV     3
# Premium Hatchback        1
# Premium Luxury Sedan     1
# Premium Midsize SUV      3
# Premium Midsize Sedan    5
# Premium Sports Coupe     4
# Premium Sports Sedan     3
# Quadricycle              1
# SUV                      8
# Sports Car               3
# Subcompact MPV           2
# Subcompact SUV           5
# Subcompact Sedan         1
# Supersports Car          2
# dtype: int64

# %%
#slicing data which has valid Ratings Data
not_na_rating_filter = data['Rating(outof10)']!='na'

# %%
data.loc[not_na_rating_filter,:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187 entries, 0 to 252
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car                  187 non-null    object
#  1   Style                187 non-null    object
#  2   Range                184 non-null    object
#  3   VehicleType          187 non-null    object
#  4   PriceRange           187 non-null    object
#  5   Rating(outof10)      187 non-null    object
#  6   Make                 187 non-null    object
#  7   max_range            184 non-null    float64
#  8   max_price            187 non-null    object
#  9   percentile_by_style  187 non-null    float64
#  10  AMT                  187 non-null    Sparse[int64, 0]
#  11  Automatic            187 non-null    Sparse[int64, 0]
#  12  Manual               187 non-null    Sparse[int64, 0]
# dtypes: Sparse[int64, 0](3), float64(2), object(8)
# memory usage: 18.9+ KB

# %%
ratings = data.loc[not_na_rating_filter,:]

# %%
#Converting Ratings from Object to Float data
ratings.loc[:, 'Rating(outof10)'] = ratings.loc[:,
                                                'Rating(outof10)'].astype(float)

# %%
ratings.loc[ratings.groupby(['Make'])['Rating(outof10)'].idxmax(), :].query(
    'Manual==1 & AMT==0 & Automatic==0')
# Out:
#                     Car Style      Range VehicleType       PriceRange  \
# 91  force motors gurkha   SUV        NaN      Diesel        ₹ 13.59 L
# 68          isuzu d-max   SUV  14.4 Km/l      Diesel  ₹ 6.87 - 8.09 L
#
#     Rating(outof10)   Make  max_range  max_price  percentile_by_style  AMT  \
# 91              6.1  force        NaN  1359000.0            7797700.0    0
# 68              8.4  isuzu       14.4   809000.0            7797700.0    0
#
#     Automatic  Manual
# 91          0       1
# 68          0       1
