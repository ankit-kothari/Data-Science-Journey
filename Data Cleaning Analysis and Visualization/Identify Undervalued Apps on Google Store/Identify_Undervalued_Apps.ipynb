# %% [markdown]
# ### Business Goal

# %% [raw]
# Business Goal: Develop a prototye to improve the revenue of undervalued apps to motivate the developers to keep working on them and give insigths on the feasability of the project

# %% [raw]
# Constrains
#     1. No budget for marketing to increase revenue by Sales.
# Refined Goal
#     1. Determine which paid apps are undervalued (undervalued here means that their price could be increased without lowering demand).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
import warnings
warnings.filterwarnings('ignore')
style.use('default')
import seaborn as sns
playstore = pd.read_csv("googleplaystore.csv")
print(playstore.shape)
# Out:
# (10841, 13)

# %% [markdown]
# ### Cleaning the Data

# %%
playstore.iloc[10472:10475]
# Out:
#                                            App       Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame            1.9    19.0    3.0M
# 10473                  osmino Wi-Fi: free WiFi          TOOLS     4.2  134203
# 10474                             Sat-Fi Voice  COMMUNICATION     3.4      37
#
#          Size     Installs  Type     Price Content Rating             Genres  \
# 10472  1,000+         Free     0  Everyone            NaN  February 11, 2018
# 10473    4.1M  10,000,000+  Free         0       Everyone              Tools
# 10474     14M       1,000+  Free         0       Everyone      Communication
#
#             Last Updated Current Ver Android Ver
# 10472             1.0.19  4.0 and up         NaN
# 10473     August 7, 2018     6.06.14  4.4 and up
# 10474  November 21, 2014     2.2.1.5  2.2 and up

# %%
playstore.drop(labels=10472,inplace=True)

# %%
playstore['Price']=playstore['Price'].str.replace('$','').astype('float')

# %%
paid = playstore[playstore['Price']!=0].copy()

# %%
paid.drop(columns=['Type'],inplace=True)

# %%
paid['Reviews']=paid['Reviews'].astype('float')

# %%
def clean_size(size):
    """Convert file size string to float and megabytes"""
    size = size.replace("M","")
    if size.endswith("k"):
        size = float(size[:-1])/1000
    elif size == "Varies with device":
        size = pd.np.NaN
    else:
        size = float(size)
    return size

# %%
paid['Size']=paid['Size'].apply(clean_size)
paid['Price']=paid['Price'].astype(int)

# %%
paid['Size'].value_counts(bins=5)
# Out:
# (-0.087, 20.011]    479
# (20.011, 40.008]    126
# (40.008, 60.006]     66
# (60.006, 80.003]     32
# (80.003, 100.0]      21
# Name: Size, dtype: int64

# %%
paid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 234 to 10798
# Data columns (total 12 columns):
# App               800 non-null object
# Category          800 non-null object
# Rating            647 non-null float64
# Reviews           800 non-null float64
# Size              724 non-null float64
# Installs          800 non-null object
# Price             800 non-null int64
# Content Rating    800 non-null object
# Genres            800 non-null object
# Last Updated      800 non-null object
# Current Ver       798 non-null object
# Android Ver       799 non-null object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 81.2+ KB

# %% [markdown]
# ### Investigating Duplicates

# %%
paid[paid.duplicated()]
# Out:
#                                                     App            Category  \
# 290       TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                      Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 1347                                        Pocket Yoga  HEALTH_AND_FITNESS
# 2202                                  Avokiddo Emotions              FAMILY
# 2203                                Nighty Night Circus              FAMILY
# 2204                                   Sago Mini Babies              FAMILY
# 2205                       Dr. Panda & Toto's Treehouse              FAMILY
# 2365                          Vargo Anesthesia Mega App             MEDICAL
# 2366                         Monash Uni Low FODMAP Diet             MEDICAL
# 2372   Human Anatomy Atlas 2018: Complete 3D Human Body             MEDICAL
# 2378                                       ASCCP Mobile             MEDICAL
# 2380                        Paramedic Protocol Provider             MEDICAL
# 2385                         2017 EMRA Antibiotic Guide             MEDICAL
# 2386                                Essential Anatomy 3             MEDICAL
# 2387                                           EMT PASS             MEDICAL
# 2389                                        Block Buddy             MEDICAL
# 2395                                    EMT Review Plus             MEDICAL
# 2398                             Journal Club: Medicine             MEDICAL
# 2399                                          Pedi STAT             MEDICAL
# 2400                                        AnatomyMapp             MEDICAL
# 2401                            Diabetes & Diet Tracker             MEDICAL
# 2402                            A Manual of Acupuncture             MEDICAL
# 2406                                 PTA Content Master             MEDICAL
# 2407  Muscle Premium - Human Anatomy, Kinesiology, B...             MEDICAL
# 2409         Cardiac diagnosis (heart rate, arrhythmia)             MEDICAL
# 2416            Medical ID - In Case of Emergency (ICE)             MEDICAL
# 2418                           IBM Micromedex Drug Info             MEDICAL
# 2419                     Advanced Comprehension Therapy             MEDICAL
# 2420                               Hospitalist Handbook             MEDICAL
# 2912                                Facetune - For Free         PHOTOGRAPHY
# 2950                                Facetune - For Free         PHOTOGRAPHY
# 3965                      EMT Tutor NREMT-B Study Guide             MEDICAL
# 6584                                 iBP Blood Pressure             MEDICAL
# 6595                           Blood Pressure Companion             MEDICAL
# 6911                              Beautiful Widgets Pro     PERSONALIZATION
#
#       Rating  Reviews    Size    Installs  Price Content Rating  \
# 290      4.7  11442.0   6.800    100,000+      4       Everyone
# 291      4.8  10295.0  39.000    100,000+      4       Everyone
# 1347     4.4   2107.0     NaN    100,000+      2       Everyone
# 2202     4.6     73.0  12.000      1,000+      2       Everyone
# 2203     4.3    382.0  15.000     10,000+      2       Everyone
# 2204     4.5    253.0  83.000     10,000+      3       Everyone
# 2205     4.4   3396.0   9.500     50,000+      3       Everyone
# 2365     4.6     92.0  32.000      1,000+     79       Everyone
# 2366     4.2   1135.0  12.000    100,000+      9       Everyone
# 2372     4.5   2921.0  25.000    100,000+     24       Everyone
# 2378     4.5     63.0  25.000     10,000+      9       Everyone
# 2380     4.5    171.0  20.000     10,000+     10   Everyone 10+
# 2385     4.4     12.0   3.800      1,000+     16       Everyone
# 2386     4.1   1533.0  42.000     50,000+     11     Mature 17+
# 2387     3.4     51.0   2.400      1,000+     29       Everyone
# 2389     4.0     15.0   5.000      1,000+     14       Everyone
# 2395     4.5    199.0   1.800     10,000+     11       Everyone
# 2398     4.8    216.0     NaN     10,000+      6       Everyone
# 2399     4.6    129.0   2.900     10,000+      5       Everyone
# 2400     4.1     80.0  48.000      5,000+     14       Everyone
# 2401     4.6    395.0  19.000      1,000+      9       Everyone
# 2402     3.5    214.0  68.000      1,000+     33       Everyone
# 2406     4.2     64.0  41.000      1,000+     29       Everyone
# 2407     4.2    168.0  25.000     10,000+     24       Everyone
# 2409     4.4      8.0   6.500        100+     12       Everyone
# 2416     4.6    717.0   5.400      5,000+      5       Everyone
# 2418     3.8    206.0   9.500     10,000+      2       Everyone
# 2419     NaN      3.0  62.000        100+     24       Everyone
# 2420     4.8     12.0  18.000      1,000+     19       Everyone
# 2912     4.4  49553.0  48.000  1,000,000+      5       Everyone
# 2950     4.4  49553.0  48.000  1,000,000+      5       Everyone
# 3965     4.6    625.0   8.400     10,000+      3       Everyone
# 6584     4.4    578.0   0.704     10,000+      0       Everyone
# 6595     4.2    178.0   4.800      1,000+      0       Everyone
# 6911     4.2  97890.0  14.000  1,000,000+      2       Everyone
#
#                             Genres        Last Updated         Current Ver  \
# 290                       Business      March 25, 2018               1.5.2
# 291                       Business      April 11, 2017               3.4.6
# 1347              Health & Fitness   December 22, 2015  Varies with device
# 2202        Education;Pretend Play        May 21, 2018               1.7.0
# 2203  Education;Action & Adventure       March 7, 2017                 2.6
# 2204        Education;Pretend Play    October 28, 2016                 1.1
# 2205           Casual;Pretend Play    December 9, 2014                 1.8
# 2365                       Medical       June 18, 2018                19.0
# 2366                       Medical       July 16, 2018               2.0.7
# 2372                       Medical        May 25, 2018           2018.5.47
# 2378                       Medical     October 3, 2016               2.1.1
# 2380                       Medical  September 21, 2017               1.8.3
# 2385                       Medical    January 27, 2017               1.0.5
# 2386                       Medical      August 7, 2014               1.1.3
# 2387                       Medical    October 22, 2014               2.0.2
# 2389                       Medical      August 1, 2018              7.6.14
# 2395                       Medical       June 27, 2018               3.0.5
# 2398                       Medical       June 17, 2017  Varies with device
# 2399                       Medical       April 6, 2018             3.0.1.0
# 2400                       Medical    November 5, 2013                 1.0
# 2401                       Medical       July 16, 2018               6.5.1
# 2402                       Medical     October 2, 2017              2.1.35
# 2406                       Medical   December 22, 2015                 2.1
# 2407                       Medical     August 11, 2017              7.1.17
# 2409                       Medical       July 25, 2018                   7
# 2416                       Medical        May 31, 2018               6.5.0
# 2418                       Medical      April 25, 2018              1.17.0
# 2419                       Medical     October 5, 2017                 1.2
# 2420                       Medical        June 5, 2017               6.0.4
# 2912                   Photography       July 25, 2018               1.3.1
# 2950                   Photography       July 25, 2018               1.3.1
# 3965                       Medical     January 8, 2017                 2.1
# 6584                       Medical   November 30, 2014               7.0.1
# 6595                       Medical       July 22, 2018    4.1.5 (Steglitz)
# 6911               Personalization     August 24, 2016               5.7.8
#
#              Android Ver
# 290           4.0 and up
# 291           3.0 and up
# 1347  Varies with device
# 2202        4.0.3 and up
# 2203          2.3 and up
# 2204        4.0.3 and up
# 2205          4.0 and up
# 2365        4.0.3 and up
# 2366          4.0 and up
# 2372          5.0 and up
# 2378          2.2 and up
# 2380          4.1 and up
# 2385        4.0.3 and up
# 2386        4.0.3 and up
# 2387          4.0 and up
# 2389          4.0 and up
# 2395         4.4W and up
# 2398  Varies with device
# 2399          4.1 and up
# 2400          3.0 and up
# 2401          5.0 and up
# 2402          4.0 and up
# 2406          2.2 and up
# 2407          4.4 and up
# 2409          3.0 and up
# 2416          5.0 and up
# 2418          4.0 and up
# 2419        4.0.3 and up
# 2420          4.1 and up
# 2912          4.1 and up
# 2950          4.1 and up
# 3965          2.1 and up
# 6584          2.2 and up
# 6595          4.1 and up
# 6911          2.3 and up

# %%
paid[paid['App']=='iBP Blood Pressure']
# Out:
#                      App Category  Rating  Reviews   Size Installs  Price  \
# 2244  iBP Blood Pressure  MEDICAL     4.4    578.0  0.704  10,000+      0
# 6584  iBP Blood Pressure  MEDICAL     4.4    578.0  0.704  10,000+      0
#
#      Content Rating   Genres       Last Updated Current Ver Android Ver
# 2244       Everyone  Medical  November 30, 2014       7.0.1  2.2 and up
# 6584       Everyone  Medical  November 30, 2014       7.0.1  2.2 and up

# %%
paid.duplicated(subset=['App']).sum()
# Out:
# 44

# %%
print(
    "Number of rows before dropping duplicates: {}".format(paid.shape[0])
)
paid.drop_duplicates(inplace=True)
print(
    "Number of rows after dropping duplicates: {}".format(paid.shape[0])
)
# Out:
# Number of rows before dropping duplicates: 800
# Number of rows after dropping duplicates: 765

# %%
paid[paid.duplicated(subset=['App'], keep=False)].sort_values(by=['App'])
# Out:
#                                                    App         Category  \
# 6652                                       Camera FV-5      PHOTOGRAPHY
# 2913                                       Camera FV-5      PHOTOGRAPHY
# 8785                      Dr. Panda & Toto's Treehouse           FAMILY
# 2192                      Dr. Panda & Toto's Treehouse           FAMILY
# 852             Fuzzy Numbers: Pre-K Number Foundation        EDUCATION
# 4301            Fuzzy Numbers: Pre-K Number Foundation           FAMILY
# 6919                                        HD Widgets  PERSONALIZATION
# 3405                                        HD Widgets  PERSONALIZATION
# 2251  Human Anatomy Atlas 2018: Complete 3D Human Body          MEDICAL
# 9574  Human Anatomy Atlas 2018: Complete 3D Human Body          MEDICAL
# 2241                                         Minecraft           FAMILY
# 4347                                         Minecraft           FAMILY
# 571                          Moco+ - Chat, Meet People           DATING
# 476                          Moco+ - Chat, Meet People           DATING
# 1831                                  The Game of Life             GAME
# 9569                                  The Game of Life             GAME
# 2151                                   Toca Life: City           FAMILY
# 853                                    Toca Life: City        EDUCATION
#
#       Rating    Reviews  Size     Installs  Price Content Rating  \
# 6652     3.8    16317.0   NaN     100,000+      3       Everyone
# 2913     3.8    16320.0   NaN     100,000+      3       Everyone
# 8785     4.4     3397.0   9.5      50,000+      3       Everyone
# 2192     4.4     3396.0   9.5      50,000+      3       Everyone
# 852      4.7       21.0  44.0       1,000+      5       Everyone
# 4301     4.7       21.0  44.0       1,000+      5       Everyone
# 6919     4.3    58614.0  26.0   1,000,000+      0       Everyone
# 3405     4.3    58617.0  26.0   1,000,000+      0       Everyone
# 2251     4.5     2921.0  25.0     100,000+     24       Everyone
# 9574     4.5     2923.0  25.0     100,000+     24       Everyone
# 2241     4.5  2376564.0   NaN  10,000,000+      6   Everyone 10+
# 4347     4.5  2375336.0   NaN  10,000,000+      6   Everyone 10+
# 571      4.2     1546.0   NaN      10,000+      3     Mature 17+
# 476      4.2     1545.0   NaN      10,000+      3     Mature 17+
# 1831     4.4    18621.0  63.0     100,000+      2       Everyone
# 9569     4.4    18652.0  63.0     100,000+      2       Everyone
# 2151     4.7    31100.0  24.0     500,000+      3       Everyone
# 853      4.7    31085.0  24.0     500,000+      3       Everyone
#
#                          Genres       Last Updated         Current Ver  \
# 6652                Photography  November 10, 2017  Varies with device
# 2913                Photography  November 10, 2017  Varies with device
# 8785        Casual;Pretend Play   December 9, 2014                 1.8
# 2192        Casual;Pretend Play   December 9, 2014                 1.8
# 852         Education;Education      July 21, 2017                 1.3
# 4301        Education;Education      July 21, 2017                 1.3
# 6919            Personalization   December 7, 2016               4.3.2
# 3405            Personalization   December 7, 2016               4.3.2
# 2251                    Medical       May 25, 2018           2018.5.47
# 9574                    Medical       May 25, 2018           2018.5.47
# 2241  Arcade;Action & Adventure      July 24, 2018             1.5.2.1
# 4347  Arcade;Action & Adventure      July 24, 2018             1.5.2.1
# 571                      Dating      June 19, 2018             2.6.139
# 476                      Dating      June 19, 2018             2.6.139
# 1831                      Board       July 4, 2018               2.1.2
# 9569                      Board       July 4, 2018               2.1.2
# 2151     Education;Pretend Play       July 6, 2018            1.5-play
# 853      Education;Pretend Play       July 6, 2018            1.5-play
#
#              Android Ver
# 6652  Varies with device
# 2913  Varies with device
# 8785          4.0 and up
# 2192          4.0 and up
# 852           4.1 and up
# 4301          4.1 and up
# 6919          4.4 and up
# 3405          4.4 and up
# 2251          5.0 and up
# 9574          5.0 and up
# 2241  Varies with device
# 4347  Varies with device
# 571           4.1 and up
# 476           4.1 and up
# 1831          4.4 and up
# 9569          4.4 and up
# 2151          4.4 and up
# 853           4.4 and up

# %%
paid.drop([2151,4301],inplace=True)

# %%
paid=paid.sort_values(by=['Reviews'], ascending=False)
paid.drop_duplicates(subset='App',keep='first',inplace=True)

# %%
paid.duplicated("App").sum()
# Out:
# 0

# %%
paid=paid.reset_index(drop=True)

# %%
paid.head()
# Out:
#                              App Category  Rating    Reviews  Size  \
# 0                      Minecraft   FAMILY     4.5  2376564.0   NaN
# 1                  Hitman Sniper     GAME     4.6   408292.0  29.0
# 2  Grand Theft Auto: San Andreas     GAME     4.4   348962.0  26.0
# 3                    Bloons TD 5   FAMILY     4.6   190086.0  94.0
# 4              Where's My Water?   FAMILY     4.7   188740.0  69.0
#
#       Installs  Price Content Rating                     Genres  \
# 0  10,000,000+      6   Everyone 10+  Arcade;Action & Adventure
# 1  10,000,000+      0     Mature 17+                     Action
# 2   1,000,000+      6     Mature 17+                     Action
# 3   1,000,000+      2       Everyone                   Strategy
# 4   1,000,000+      1       Everyone         Puzzle;Brain Games
#
#      Last Updated Current Ver         Android Ver
# 0   July 24, 2018     1.5.2.1  Varies with device
# 1   July 12, 2018  1.7.110758          4.1 and up
# 2  March 21, 2015        1.08          3.0 and up
# 3   July 13, 2018        3.16        2.3.3 and up
# 4    July 5, 2018      1.16.0          4.2 and up

# %% [markdown]
# ### Exploring the Price and Rating

# %%
def data_distribution(column):
 f, ((ax1, ax2), (ax3,ax4)) = plt.subplots(2,2,figsize=(16,8))
 sns.swarmplot(x=column, ax=ax1)
 sns.boxplot(x=column,ax=ax2)
 sns.histplot(data=paid, x=column, ax=ax3, bins=10)
 sns.kdeplot(data=paid, x=column,ax=ax4)

 axes = [ax1, ax2, ax3, ax4]

 ### Changes to all the subplots
 for ax in axes:
    ax.tick_params(bottom=False, left=False,top=False)
    for location in ['left', 'right', 'bottom', 'top']:
       ax.spines[location].set_visible(False)  #used to remove the splines

# %% [markdown]
# #### Outliers affecting the Price Distribution, which is skewed towards less than 50

# %%
data_distribution(paid["Price"])

# %%
affordable_apps = paid[paid["Price"]<50].copy()

# %% [markdown]
# #### Outliers affecting the Price Distribution, even for prices than 50

# %%
data_distribution(affordable_apps["Price"])

# %% [markdown]
# #### Creating Masks for Apps Prices below 5 as Cheap and above 5 as Reasonable

# %%
cheap = affordable_apps["Price"] < 5
reasonable = affordable_apps["Price"] >= 5

# %%
data_distribution(affordable_apps[cheap]["Price"])

# %%
data_distribution(affordable_apps[reasonable]["Price"])

# %%
affordable_apps.head()
# Out:
#                              App Category  Rating    Reviews  Size  \
# 0                      Minecraft   FAMILY     4.5  2376564.0   NaN
# 1                  Hitman Sniper     GAME     4.6   408292.0  29.0
# 2  Grand Theft Auto: San Andreas     GAME     4.4   348962.0  26.0
# 3                    Bloons TD 5   FAMILY     4.6   190086.0  94.0
# 4              Where's My Water?   FAMILY     4.7   188740.0  69.0
#
#       Installs  Price Content Rating                     Genres  \
# 0  10,000,000+      6   Everyone 10+  Arcade;Action & Adventure
# 1  10,000,000+      0     Mature 17+                     Action
# 2   1,000,000+      6     Mature 17+                     Action
# 3   1,000,000+      2       Everyone                   Strategy
# 4   1,000,000+      1       Everyone         Puzzle;Brain Games
#
#      Last Updated Current Ver         Android Ver
# 0   July 24, 2018     1.5.2.1  Varies with device
# 1   July 12, 2018  1.7.110758          4.1 and up
# 2  March 21, 2015        1.08          3.0 and up
# 3   July 13, 2018        3.16        2.3.3 and up
# 4    July 5, 2018      1.16.0          4.2 and up

# %% [markdown]
# #### Adding Coulmns for Affordability

# %%
affordable_apps["affordability"] = affordable_apps['Price'].apply(lambda x: "cheap" if x < 5 else "reasonable")

# %% [markdown]
# #### Calculating co-relation between Price and Rating

# %%
print(affordable_apps[cheap].corr().loc["Rating", "Price"])
# Out:
# -0.056252687823296024

# %% [raw]
# We can increase the price of those apps that cost less than, say, the mean cheap price, to the mean cheap price. We can then monitor the behavior of these apps — possibly by using statistical techniques like hypothesis testing, — to confirm that there is an increase in profits.

# %%
cheap_mean = affordable_apps[cheap]['Price'].mean()

# %%
reasonable_mean= affordable_apps.loc[reasonable,'Price'].mean()

# %%
affordable_apps.loc[cheap,'price_criterion']=affordable_apps.loc[cheap,'Price'].apply(lambda x: 1 if x<cheap_mean else 0)

# %%
affordable_apps.head()
# Out:
#                              App Category  Rating    Reviews  Size  \
# 0                      Minecraft   FAMILY     4.5  2376564.0   NaN
# 1                  Hitman Sniper     GAME     4.6   408292.0  29.0
# 2  Grand Theft Auto: San Andreas     GAME     4.4   348962.0  26.0
# 3                    Bloons TD 5   FAMILY     4.6   190086.0  94.0
# 4              Where's My Water?   FAMILY     4.7   188740.0  69.0
#
#       Installs  Price Content Rating                     Genres  \
# 0  10,000,000+      6   Everyone 10+  Arcade;Action & Adventure
# 1  10,000,000+      0     Mature 17+                     Action
# 2   1,000,000+      6     Mature 17+                     Action
# 3   1,000,000+      2       Everyone                   Strategy
# 4   1,000,000+      1       Everyone         Puzzle;Brain Games
#
#      Last Updated Current Ver         Android Ver affordability  \
# 0   July 24, 2018     1.5.2.1  Varies with device    reasonable
# 1   July 12, 2018  1.7.110758          4.1 and up         cheap
# 2  March 21, 2015        1.08          3.0 and up    reasonable
# 3   July 13, 2018        3.16        2.3.3 and up         cheap
# 4    July 5, 2018      1.16.0          4.2 and up         cheap
#
#    price_criterion
# 0              NaN
# 1              1.0
# 2              NaN
# 3              0.0
# 4              1.0

# %%
affordable_apps.loc[reasonable,'price_criterion']=affordable_apps.loc[reasonable,'Price'].apply(lambda x: 1 if x<reasonable_mean else 0)

# %%
affordable_apps.head()
# Out:
#                              App Category  Rating    Reviews  Size  \
# 0                      Minecraft   FAMILY     4.5  2376564.0   NaN
# 1                  Hitman Sniper     GAME     4.6   408292.0  29.0
# 2  Grand Theft Auto: San Andreas     GAME     4.4   348962.0  26.0
# 3                    Bloons TD 5   FAMILY     4.6   190086.0  94.0
# 4              Where's My Water?   FAMILY     4.7   188740.0  69.0
#
#       Installs  Price Content Rating                     Genres  \
# 0  10,000,000+      6   Everyone 10+  Arcade;Action & Adventure
# 1  10,000,000+      0     Mature 17+                     Action
# 2   1,000,000+      6     Mature 17+                     Action
# 3   1,000,000+      2       Everyone                   Strategy
# 4   1,000,000+      1       Everyone         Puzzle;Brain Games
#
#      Last Updated Current Ver         Android Ver affordability  \
# 0   July 24, 2018     1.5.2.1  Varies with device    reasonable
# 1   July 12, 2018  1.7.110758          4.1 and up         cheap
# 2  March 21, 2015        1.08          3.0 and up    reasonable
# 3   July 13, 2018        3.16        2.3.3 and up         cheap
# 4    July 5, 2018      1.16.0          4.2 and up         cheap
#
#    price_criterion
# 0              1.0
# 1              1.0
# 2              1.0
# 3              0.0
# 4              1.0

# %%
affordable_apps[cheap].plot(kind="scatter", x="Price", y="Rating")

# %%
affordable_apps[reasonable].plot(kind="scatter", x="Price", y="Rating")

# %%
print(affordable_apps[cheap].corr().loc['Rating','Price'])
# Out:
# -0.056252687823296024

# %% [markdown]
# ### Exploring Price Vs Category/Genre

# %%
affordable_apps['Category'].unique()
# Out:
# array(['FAMILY', 'GAME', 'SPORTS', 'PERSONALIZATION', 'PRODUCTIVITY',
#        'WEATHER', 'TOOLS', 'COMMUNICATION', 'PHOTOGRAPHY', 'EDUCATION',
#        'LIFESTYLE', 'FINANCE', 'HEALTH_AND_FITNESS', 'TRAVEL_AND_LOCAL',
#        'BUSINESS', 'PARENTING', 'ENTERTAINMENT', 'MAPS_AND_NAVIGATION',
#        'VIDEO_PLAYERS', 'MEDICAL', 'AUTO_AND_VEHICLES', 'FOOD_AND_DRINK',
#        'DATING', 'BOOKS_AND_REFERENCE', 'ART_AND_DESIGN', 'SHOPPING',
#        'SOCIAL', 'NEWS_AND_MAGAZINES', 'LIBRARIES_AND_DEMO'], dtype=object)

# %%
affordable_apps['Genres'].unique()
# Out:
# array(['Arcade;Action & Adventure', 'Action', 'Strategy',
#        'Puzzle;Brain Games', 'Card;Action & Adventure', 'Sports',
#        'Personalization', 'Arcade', 'Puzzle', 'Productivity', 'Weather',
#        'Tools', 'Sports;Action & Adventure', 'Communication',
#        'Role Playing', 'Photography', 'Card', 'Simulation;Education',
#        'Adventure', 'Education;Pretend Play', 'Lifestyle',
#        'Strategy;Action & Adventure', 'Board', 'Finance',
#        'Health & Fitness', 'Role Playing;Action & Adventure', 'Music',
#        'Travel & Local', 'Business', 'Simulation',
#        'Adventure;Action & Adventure', 'Parenting',
#        'Adventure;Brain Games', 'Entertainment', 'Maps & Navigation',
#        'Video Players & Editors', 'Racing', 'Medical', 'Auto & Vehicles',
#        'Educational;Pretend Play', 'Casual;Pretend Play',
#        'Education;Creativity', 'Education', 'Board;Brain Games',
#        'Food & Drink', 'Action;Action & Adventure',
#        'Simulation;Pretend Play', 'Dating', 'Books & Reference',
#        'Art & Design', 'Racing;Action & Adventure', 'Casual',
#        'Education;Education', 'Educational;Education', 'Casual;Education',
#        'Shopping', 'Books & Reference;Education',
#        'Education;Action & Adventure', 'Board;Action & Adventure',
#        'Social', 'Casual;Action & Adventure', 'News & Magazines',
#        'Music;Music & Video', 'Educational;Creativity', 'Casino',
#        'Educational', 'Books & Reference;Creativity',
#        'Board;Pretend Play', 'Libraries & Demo', 'Education;Brain Games',
#        'Role Playing;Education'], dtype=object)

# %%
affordable_apps["genre_count"] = affordable_apps["Genres"].str.count(";")+1

# %%
genres_mean = affordable_apps.groupby(
    ["affordability", "genre_count"]
).mean()[["Price"]]
genres_mean
# Out:
#                                Price
# affordability genre_count
# cheap         1             1.631380
#               2             2.208955
# reasonable    1            11.679104
#               2             6.000000

# %%
genres_mean.loc["cheap",2]['Price']
# Out:
# 2.208955223880597

# %%
def label_genres(row):
    """For each segment in `genres_mean`,
    labels the apps that cost less than its segment's mean with `1`
    and the others with `0`."""

    aff = row["affordability"]
    gc = row["genre_count"]
    price = row["Price"]

    if price < genres_mean.loc[(aff, gc)][0]:
        return 1
    else:
        return 0

affordable_apps["genre_criterion"] = affordable_apps.apply(
    label_genres, axis="columns"
)

# %%
categories_mean= affordable_apps.groupby(["affordability", "Category"]).mean()['Price']

# %%
categories_mean
# Out:
# affordability  Category
# cheap          ART_AND_DESIGN          1.000000
#                AUTO_AND_VEHICLES       1.000000
#                BOOKS_AND_REFERENCE     1.714286
#                BUSINESS                2.714286
#                COMMUNICATION           1.576923
#                DATING                  2.250000
#                EDUCATION               3.000000
#                ENTERTAINMENT           3.000000
#                FAMILY                  1.850649
#                FINANCE                 2.500000
#                FOOD_AND_DRINK          3.500000
#                GAME                    1.597222
#                HEALTH_AND_FITNESS      2.090909
#                LIBRARIES_AND_DEMO      0.000000
#                LIFESTYLE               2.100000
#                MAPS_AND_NAVIGATION     0.666667
#                MEDICAL                 1.833333
#                NEWS_AND_MAGAZINES      1.000000
#                PARENTING               4.000000
#                PERSONALIZATION         0.873418
#                PHOTOGRAPHY             2.214286
#                PRODUCTIVITY            1.772727
#                SHOPPING                2.000000
#                SOCIAL                  0.000000
#                SPORTS                  1.954545
#                TOOLS                   1.718310
#                TRAVEL_AND_LOCAL        2.111111
#                VIDEO_PLAYERS           0.666667
#                WEATHER                 2.333333
# reasonable     AUTO_AND_VEHICLES       9.000000
#                BOOKS_AND_REFERENCE     5.285714
#                BUSINESS               14.000000
#                COMMUNICATION          19.000000
#                DATING                  6.500000
#                EDUCATION               5.000000
#                FAMILY                 14.520000
#                FINANCE                20.250000
#                GAME                    9.200000
#                HEALTH_AND_FITNESS      6.750000
#                LIFESTYLE              16.333333
#                MAPS_AND_NAVIGATION    10.000000
#                MEDICAL                12.947368
#                PERSONALIZATION         7.500000
#                PHOTOGRAPHY            14.200000
#                PRODUCTIVITY            6.800000
#                SOCIAL                 13.000000
#                SPORTS                 18.500000
#                TOOLS                  10.857143
#                TRAVEL_AND_LOCAL        7.000000
#                VIDEO_PLAYERS           5.000000
#                WEATHER                 5.500000
# Name: Price, dtype: float64

# %%
categories_mean.loc['cheap','WEATHER']
# Out:
# 2.3333333333333335

# %%
def label_categories(row):
    x=row['affordability']
    y=row['Category']
    #print(categories_mean.loc[(x,y)]['Price'])
    if row['Price']  < categories_mean.loc[(x,y)]:
      return 1
    else:
       return 0

affordable_apps['category_criterion']=affordable_apps.apply(label_categories, axis="columns")

# %%
affordable_apps.head()
# Out:
#                              App Category  Rating    Reviews  Size  \
# 0                      Minecraft   FAMILY     4.5  2376564.0   NaN
# 1                  Hitman Sniper     GAME     4.6   408292.0  29.0
# 2  Grand Theft Auto: San Andreas     GAME     4.4   348962.0  26.0
# 3                    Bloons TD 5   FAMILY     4.6   190086.0  94.0
# 4              Where's My Water?   FAMILY     4.7   188740.0  69.0
#
#       Installs  Price Content Rating                     Genres  \
# 0  10,000,000+      6   Everyone 10+  Arcade;Action & Adventure
# 1  10,000,000+      0     Mature 17+                     Action
# 2   1,000,000+      6     Mature 17+                     Action
# 3   1,000,000+      2       Everyone                   Strategy
# 4   1,000,000+      1       Everyone         Puzzle;Brain Games
#
#      Last Updated Current Ver         Android Ver affordability  \
# 0   July 24, 2018     1.5.2.1  Varies with device    reasonable
# 1   July 12, 2018  1.7.110758          4.1 and up         cheap
# 2  March 21, 2015        1.08          3.0 and up    reasonable
# 3   July 13, 2018        3.16        2.3.3 and up         cheap
# 4    July 5, 2018      1.16.0          4.2 and up         cheap
#
#    price_criterion  genre_count  genre_criterion  category_criterion
# 0              1.0            2                0                   1
# 1              1.0            1                1                   1
# 2              1.0            1                1                   1
# 3              0.0            1                0                   0
# 4              1.0            2                1                   1

# %%
criteria = ["price_criterion", "genre_criterion", "category_criterion"]
affordable_apps["Result"] = affordable_apps[criteria].mode(axis='columns')

affordable_apps.sample(5)
# Out:
#                                 App          Category  Rating  Reviews   Size  \
# 26    Stickman Legends: Shadow Wars              GAME     4.4  38419.0  100.0
# 235                TV Guide BR Gold            FAMILY     4.4    544.0    NaN
# 286                Sago Mini Babies            FAMILY     4.5    253.0   83.0
# 675  Es-Bg Offline Voice Translator  TRAVEL_AND_LOCAL     NaN      1.0   87.0
# 47                             Clue              GAME     4.6  19922.0   35.0
#
#        Installs  Price Content Rating                  Genres  \
# 26   1,000,000+      0   Everyone 10+                  Action
# 235      5,000+      1       Everyone           Entertainment
# 286     10,000+      3       Everyone  Education;Pretend Play
# 675         10+      1       Everyone          Travel & Local
# 47     100,000+      1   Everyone 10+                   Board
#
#          Last Updated         Current Ver         Android Ver affordability  \
# 26     August 3, 2018              2.3.24          4.1 and up         cheap
# 235   August 20, 2017  Varies with device  Varies with device         cheap
# 286  October 28, 2016                 1.1        4.0.3 and up         cheap
# 675    March 19, 2017                2.55          3.0 and up         cheap
# 47      July 30, 2018               2.2.5          5.0 and up         cheap
#
#      price_criterion  genre_count  genre_criterion  category_criterion  Result
# 26               1.0            1                1                   1     1.0
# 235              1.0            1                1                   1     1.0
# 286              0.0            2                0                   0     0.0
# 675              1.0            1                1                   1     1.0
# 47               1.0            1                1                   1     1.0

# %% [markdown]
# ### Results & Impact

# %%
nr_eligible = affordable_apps["Result"].sum()
print(nr_eligible, nr_eligible/affordable_apps.shape[0], sep="\n")
# Out:
# 371.0
# 0.5061391541609823

# %%
affordable_apps.loc[cheap,'New_Price']=affordable_apps.apply(lambda row: round(max(row['Price'],cheap_mean),2),axis="columns")
affordable_apps.loc[reasonable,'New_Price']=affordable_apps.apply(lambda row: round(max(row['Price'],reasonable_mean),2),axis="columns")

# %%
affordable_apps
# Out:
#                                                    App             Category  \
# 0                                            Minecraft               FAMILY
# 1                                        Hitman Sniper                 GAME
# 2                        Grand Theft Auto: San Andreas                 GAME
# 3                                          Bloons TD 5               FAMILY
# 4                                    Where's My Water?               FAMILY
# 5                           Card Wars - Adventure Time               FAMILY
# 6                                           True Skate               SPORTS
# 7                              Five Nights at Freddy's                 GAME
# 8                                Beautiful Widgets Pro      PERSONALIZATION
# 9                                  DraStic DS Emulator                 GAME
# 10                                 Fruit Ninja Classic                 GAME
# 11                                           Hitman GO               FAMILY
# 12                        ES File Explorer/Manager PRO         PRODUCTIVITY
# 13                                        Weather Live              WEATHER
# 14                           Five Nights at Freddy's 2               FAMILY
# 15                                   Cut the Rope GOLD               FAMILY
# 16                                          HD Widgets      PERSONALIZATION
# 17                       ai.type keyboard Plus + Emoji                TOOLS
# 18                               NBA JAM by EA SPORTS™               FAMILY
# 19                                             Threema        COMMUNICATION
# 20                                       Day R Premium               FAMILY
# 21                                 Facetune - For Free          PHOTOGRAPHY
# 22                          Ski Safari: Adventure Time               FAMILY
# 23                                              Tasker                TOOLS
# 24                           Assassin's Creed Identity                 GAME
# 25                                Smart Launcher Pro 3      PERSONALIZATION
# 26                       Stickman Legends: Shadow Wars                 GAME
# 27                                  Star Wars ™: DIRTY                 GAME
# 28                                            Skip-Bo™                 GAME
# 29                                Farming Simulator 16               FAMILY
# ..                                                 ...                  ...
# 723                             F-1 watchface by Delta      PERSONALIZATION
# 724                                 EP McGuffey Primer               FAMILY
# 725                      Norwegian For Kids & Babies F               FAMILY
# 726                                     KeePass DX Pro                TOOLS
# 727                 iCluster - The DX-Cluster database        COMMUNICATION
# 728                                             amm dz              FINANCE
# 729                                           Dz kayas              FINANCE
# 730  Be the Expert in Phlebotomy - Professional Nur...              MEDICAL
# 731                           EG | Explore Folegandros     TRAVEL_AND_LOCAL
# 732                                          OrthoFlow              MEDICAL
# 733                               Cargo de Praça PM DF         PRODUCTIVITY
# 734                         D.C. Driving/Walking Tours     TRAVEL_AND_LOCAL
# 735                                      CI Attendance         PRODUCTIVITY
# 736                                       EU RCD Guide  BOOKS_AND_REFERENCE
# 737                                            Z PIVOT        COMMUNICATION
# 738                                          Visualmed              MEDICAL
# 739                 CW Ringtone (Morse Code generator)        COMMUNICATION
# 740                                           Learn CW               FAMILY
# 741                                        P Icon Pack               FAMILY
# 743                             CZ-52 pistol explained  BOOKS_AND_REFERENCE
# 745                                        Eu sou Rico              FINANCE
# 746       Popsicle Launcher for Android P 9.0 launcher      PERSONALIZATION
# 747                      Pistolet CZ-70 CZ-50 expliqué  BOOKS_AND_REFERENCE
# 748                     CZ-38 (vz 38) pistol explained  BOOKS_AND_REFERENCE
# 749                                       Reksio cz. 1  BOOKS_AND_REFERENCE
# 750    Pureness Pacify (Android P) - Theme for Xperia™      PERSONALIZATION
# 751                     ReDNAKET DB Normalization Tool                TOOLS
# 753     db Meter - sound level meter with data logging                TOOLS
# 754                                          EP Coding              MEDICAL
# 755                               Word Search Tab 1 FR               FAMILY
#
#      Rating    Reviews     Size     Installs  Price Content Rating  \
# 0       4.5  2376564.0      NaN  10,000,000+      6   Everyone 10+
# 1       4.6   408292.0   29.000  10,000,000+      0     Mature 17+
# 2       4.4   348962.0   26.000   1,000,000+      6     Mature 17+
# 3       4.6   190086.0   94.000   1,000,000+      2       Everyone
# 4       4.7   188740.0   69.000   1,000,000+      1       Everyone
# 5       4.3   129603.0   23.000   1,000,000+      2   Everyone 10+
# 6       4.4   129409.0   73.000   1,000,000+      1       Everyone
# 7       4.6   100805.0   50.000   1,000,000+      2           Teen
# 8       4.2    97890.0   14.000   1,000,000+      2       Everyone
# 9       4.6    87766.0   12.000   1,000,000+      4       Everyone
# 10      4.3    85468.0   36.000   1,000,000+      0       Everyone
# 11      4.6    84114.0   23.000     500,000+      0   Everyone 10+
# 12      4.7    81614.0    6.600     500,000+      2       Everyone
# 13      4.5    76593.0      NaN     500,000+      5       Everyone
# 14      4.6    73919.0   40.000     500,000+      2           Teen
# 15      4.6    61264.0   43.000   1,000,000+      0       Everyone
# 16      4.3    58617.0   26.000   1,000,000+      0       Everyone
# 17      4.5    57076.0   35.000     100,000+      4       Everyone
# 18      4.3    56444.0   43.000     500,000+      4       Everyone
# 19      4.5    51110.0      NaN   1,000,000+      2       Everyone
# 20      4.8    51068.0   57.000     100,000+      4           Teen
# 21      4.4    49553.0   48.000   1,000,000+      5       Everyone
# 22      4.5    48754.0    9.300     100,000+      0       Everyone
# 23      4.6    43045.0      NaN   1,000,000+      2       Everyone
# 24      3.7    42529.0   92.000     500,000+      1           Teen
# 25      4.6    40704.0      NaN     100,000+      4       Everyone
# 26      4.4    38419.0  100.000   1,000,000+      0   Everyone 10+
# 27      4.5    38207.0   15.000     100,000+      9           Teen
# 28      4.4    33661.0   60.000     100,000+      2       Everyone
# 29      4.2    32812.0   14.000     500,000+      2       Everyone
# ..      ...        ...      ...          ...    ...            ...
# 723     NaN        0.0      NaN          10+      2       Everyone
# 724     NaN        0.0      NaN          50+      1       Everyone
# 725     NaN        0.0   14.000           5+     39       Everyone
# 726     NaN        0.0      NaN         100+      5       Everyone
# 727     NaN        0.0   17.000          10+      0       Everyone
# 728     NaN        0.0   14.000           1+      5       Everyone
# 729     NaN        0.0   14.000           1+     28       Everyone
# 730     NaN        0.0    5.000           1+      0       Everyone
# 731     NaN        0.0   56.000           0+      3       Everyone
# 732     NaN        0.0   66.000          10+      5       Everyone
# 733     NaN        0.0    5.200          10+      2       Everyone
# 734     NaN        0.0   32.000          50+      4       Everyone
# 735     NaN        0.0    0.172           5+      0       Everyone
# 736     NaN        0.0   45.000          10+      3       Everyone
# 737     NaN        0.0    5.700          10+     19       Everyone
# 738     NaN        0.0    3.100           1+      2       Everyone
# 739     NaN        0.0    0.269          10+      2       Everyone
# 740     NaN        0.0   21.000           1+      2       Everyone
# 741     NaN        0.0   21.000          10+      0       Everyone
# 743     NaN        0.0    9.300          10+      5       Everyone
# 745     NaN        0.0    2.600           0+     30       Everyone
# 746     NaN        0.0    5.500           0+      1       Everyone
# 747     NaN        0.0   17.000           1+      5       Everyone
# 748     NaN        0.0   13.000           5+      5       Everyone
# 749     NaN        0.0    8.600          10+      0       Everyone
# 750     NaN        0.0    3.600           1+      1       Everyone
# 751     NaN        0.0    0.940          10+      0       Everyone
# 753     NaN        0.0   15.000           1+      1       Everyone
# 754     NaN        0.0    2.000          50+      0       Everyone
# 755     NaN        0.0    1.020          50+      1       Everyone
#
#                         Genres        Last Updated         Current Ver  \
# 0    Arcade;Action & Adventure       July 24, 2018             1.5.2.1
# 1                       Action       July 12, 2018          1.7.110758
# 2                       Action      March 21, 2015                1.08
# 3                     Strategy       July 13, 2018                3.16
# 4           Puzzle;Brain Games        July 5, 2018              1.16.0
# 5      Card;Action & Adventure   February 11, 2016              1.11.0
# 6                       Sports      August 4, 2018               1.5.1
# 7                       Action    December 2, 2014                1.85
# 8              Personalization     August 24, 2016               5.7.8
# 9                       Action       July 19, 2016           r2.5.0.3a
# 10                      Arcade        June 8, 2018        2.4.1.485300
# 11                      Puzzle        July 5, 2018         1.13.108869
# 12                Productivity       July 11, 2018         Pro 1.1.4.1
# 13                     Weather   November 21, 2017  Varies with device
# 14                    Strategy   November 15, 2014                1.07
# 15                      Puzzle       June 19, 2018               3.7.0
# 16             Personalization    December 7, 2016               4.3.2
# 17                       Tools       July 24, 2018        Paid-9.4.1.3
# 18   Sports;Action & Adventure    February 8, 2017            04.00.40
# 19               Communication      August 3, 2018  Varies with device
# 20                Role Playing       June 21, 2018               1.574
# 21                 Photography       July 25, 2018               1.3.1
# 22   Arcade;Action & Adventure     October 7, 2014               1.5.2
# 23                       Tools       June 25, 2018  Varies with device
# 24                      Action   November 23, 2016               2.8.2
# 25             Personalization      March 16, 2018  Varies with device
# 26                      Action      August 3, 2018              2.3.24
# 27                Role Playing    October 19, 2015               1.0.6
# 28                        Card      August 3, 2018               3.4.6
# 29        Simulation;Education      April 10, 2018             1.1.1.6
# ..                         ...                 ...                 ...
# 723            Personalization     August 23, 2017  Varies with device
# 724                  Education       July 16, 2018  Varies with device
# 725                  Education  September 24, 2015                 1.0
# 726                      Tools      August 2, 2018  Varies with device
# 727              Communication       July 26, 2018                 1.7
# 728                    Finance        July 8, 2018                 1.0
# 729                    Finance       July 12, 2018                 1.0
# 730                    Medical       July 24, 2018                 1.0
# 731             Travel & Local    January 22, 2017               1.1.1
# 732                    Medical       July 15, 2018               1.0.0
# 733               Productivity         May 7, 2018                 3.0
# 734             Travel & Local       July 27, 2018               3.8.0
# 735               Productivity     August 17, 2013               1.0.0
# 736          Books & Reference       June 29, 2016                 2.0
# 737              Communication       July 11, 2018                 1.3
# 738                    Medical      August 1, 2018                 1.0
# 739              Communication      March 16, 2018               1.0.2
# 740                  Education       April 6, 2018                 1.1
# 741              Entertainment       July 16, 2018               1.0.6
# 743          Books & Reference   September 3, 2015  Android 3.0 - 2015
# 745                    Finance     January 9, 2018                 1.0
# 746            Personalization       July 11, 2018                 1.1
# 747          Books & Reference    November 1, 2016  Android 2.0 - 2016
# 748          Books & Reference     August 10, 2017  Android 3.1 - 2017
# 749          Books & Reference      March 30, 2015               1.0.1
# 750            Personalization       July 23, 2018   1.2.A.Exceed.Paid
# 751                      Tools    February 3, 2016               1.0.2
# 753                      Tools      March 15, 2018               1.0.1
# 754                    Medical     October 5, 2017                 1.6
# 755                     Puzzle    February 6, 2012                 1.1
#
#             Android Ver affordability  price_criterion  genre_count  \
# 0    Varies with device    reasonable              1.0            2
# 1            4.1 and up         cheap              1.0            1
# 2            3.0 and up    reasonable              1.0            1
# 3          2.3.3 and up         cheap              0.0            1
# 4            4.2 and up         cheap              1.0            2
# 5          2.3.3 and up         cheap              0.0            2
# 6          4.0.3 and up         cheap              1.0            1
# 7            2.3 and up         cheap              0.0            1
# 8            2.3 and up         cheap              0.0            1
# 9            2.3 and up         cheap              0.0            1
# 10         4.0.3 and up         cheap              1.0            1
# 11         2.3.3 and up         cheap              1.0            1
# 12           4.0 and up         cheap              0.0            1
# 13   Varies with device    reasonable              1.0            1
# 14           2.3 and up         cheap              0.0            1
# 15           4.1 and up         cheap              1.0            1
# 16           4.4 and up         cheap              1.0            1
# 17           4.1 and up         cheap              0.0            1
# 18           2.3 and up         cheap              0.0            2
# 19   Varies with device         cheap              0.0            1
# 20         4.0.3 and up         cheap              0.0            1
# 21           4.1 and up    reasonable              1.0            1
# 22           2.3 and up         cheap              1.0            2
# 23   Varies with device         cheap              0.0            1
# 24           4.1 and up         cheap              1.0            1
# 25   Varies with device         cheap              0.0            1
# 26           4.1 and up         cheap              1.0            1
# 27           4.1 and up    reasonable              1.0            1
# 28           4.1 and up         cheap              0.0            1
# 29         4.0.3 and up         cheap              0.0            2
# ..                  ...           ...              ...          ...
# 723  Varies with device         cheap              0.0            1
# 724  Varies with device         cheap              1.0            1
# 725          4.0 and up    reasonable              0.0            1
# 726  Varies with device    reasonable              1.0            1
# 727          6.0 and up         cheap              1.0            1
# 728          4.2 and up    reasonable              1.0            1
# 729          4.2 and up    reasonable              0.0            1
# 730        4.0.3 and up         cheap              1.0            1
# 731          4.1 and up         cheap              0.0            1
# 732          4.2 and up    reasonable              1.0            1
# 733          4.0 and up         cheap              0.0            1
# 734          4.4 and up         cheap              0.0            1
# 735          3.1 and up         cheap              1.0            1
# 736          4.0 and up         cheap              0.0            1
# 737          4.2 and up    reasonable              0.0            1
# 738          4.1 and up         cheap              0.0            1
# 739          2.2 and up         cheap              0.0            1
# 740          4.3 and up         cheap              0.0            1
# 741        4.0.3 and up         cheap              1.0            1
# 743          1.6 and up    reasonable              1.0            1
# 745          4.0 and up    reasonable              0.0            1
# 746          4.2 and up         cheap              1.0            1
# 747          1.6 and up    reasonable              1.0            1
# 748          1.6 and up    reasonable              1.0            1
# 749        4.0.3 and up         cheap              1.0            1
# 750          6.0 and up         cheap              1.0            1
# 751          5.0 and up         cheap              1.0            1
# 753          4.1 and up         cheap              1.0            1
# 754          4.0 and up         cheap              1.0            1
# 755          3.0 and up         cheap              1.0            1
#
#      genre_criterion  category_criterion  Result  New_Price
# 0                  0                   1     1.0      11.55
# 1                  1                   1     1.0       1.70
# 2                  1                   1     1.0      11.55
# 3                  0                   0     0.0       2.00
# 4                  1                   1     1.0       1.70
# 5                  1                   0     0.0       2.00
# 6                  1                   1     1.0       1.70
# 7                  0                   0     0.0       2.00
# 8                  0                   0     0.0       2.00
# 9                  0                   0     0.0       4.00
# 10                 1                   1     1.0       1.70
# 11                 1                   1     1.0       1.70
# 12                 0                   0     0.0       2.00
# 13                 1                   1     1.0      11.55
# 14                 0                   0     0.0       2.00
# 15                 1                   1     1.0       1.70
# 16                 1                   1     1.0       1.70
# 17                 0                   0     0.0       4.00
# 18                 0                   0     0.0       4.00
# 19                 0                   0     0.0       2.00
# 20                 0                   0     0.0       4.00
# 21                 1                   1     1.0      11.55
# 22                 1                   1     1.0       1.70
# 23                 0                   0     0.0       2.00
# 24                 1                   1     1.0       1.70
# 25                 0                   0     0.0       4.00
# 26                 1                   1     1.0       1.70
# 27                 1                   1     1.0      11.55
# 28                 0                   0     0.0       2.00
# 29                 1                   0     0.0       2.00
# ..               ...                 ...     ...        ...
# 723                0                   0     0.0       2.00
# 724                1                   1     1.0       1.70
# 725                0                   0     0.0      39.00
# 726                1                   1     1.0      11.55
# 727                1                   1     1.0       1.70
# 728                1                   1     1.0      11.55
# 729                0                   0     0.0      28.00
# 730                1                   1     1.0       1.70
# 731                0                   0     0.0       3.00
# 732                1                   1     1.0      11.55
# 733                0                   0     0.0       2.00
# 734                0                   0     0.0       4.00
# 735                1                   1     1.0       1.70
# 736                0                   0     0.0       3.00
# 737                0                   0     0.0      19.00
# 738                0                   0     0.0       2.00
# 739                0                   0     0.0       2.00
# 740                0                   0     0.0       2.00
# 741                1                   1     1.0       1.70
# 743                1                   1     1.0      11.55
# 745                0                   0     0.0      30.00
# 746                1                   0     1.0       1.70
# 747                1                   1     1.0      11.55
# 748                1                   1     1.0      11.55
# 749                1                   1     1.0       1.70
# 750                1                   0     1.0       1.70
# 751                1                   1     1.0       1.70
# 753                1                   1     1.0       1.70
# 754                1                   1     1.0       1.70
# 755                1                   1     1.0       1.70
#
# [733 rows x 19 columns]

# %% [markdown]
# ### Recommendation

# %% [raw]
# - Upon casting the votes and finding the majority, out of the 733 apps that were analyzed, 401 apps (roughly 55%) were deemed eligible for a price increase.
# - To estimate the impact that increasing prices could have, we want to find the optimal price and have a sense of how many times each app will be purchased.
# - It wasn't the goal of this prototype to determine the optimal price, so as a quick proxy, we used the average price for each app's affordability. As for the amount of times each app will be purchased, we don't have access to the data, so we tried to use the number of installations instead.
# - In any case, given that roughly 60% of apps seem to be undervalued, our recommendation is that we move forward with this project.

# %% [markdown]
# ### Future Work

# %% [raw]
# We fell short on evaluating the impact due to lack of data. A possible next step would be to request data concerning the number of purchases.
#
# Before we clean up our findings for communication, let's list some possible next steps for this project:
#
# Include unused data in the analysis, specifically:
# 1. The number of reviews;
# 2. The size of the app;
# 3. The content rating;
# 4. The last time the app was updated;
# 5. The app's Android versions;
